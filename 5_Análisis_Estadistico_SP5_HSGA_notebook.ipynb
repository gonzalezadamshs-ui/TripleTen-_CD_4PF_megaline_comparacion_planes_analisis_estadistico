# %% [markdown]
# # ¡Hola Hilary! <a class="tocSkip"></a>
#
# Mi nombre es Oscar Flores y tengo el gusto de revisar tu proyecto. Si tienes algún comentario que quieras agregar en tus respuestas te puedes referir a mi como Oscar, no hay problema que me trates de tú.
#
# Si veo un error en la primera revisión solamente lo señalaré y dejaré que tú encuentres de qué se trata y cómo arreglarlo. Debo prepararte para que te desempeñes como especialista en Data, en un trabajo real, el responsable a cargo tuyo hará lo mismo. Si aún tienes dificultades para resolver esta tarea, te daré indicaciones más precisas en una siguiente iteración.
#
# Te dejaré mis comentarios más abajo - **por favor, no los muevas, modifiques o borres**
#
# Comenzaré mis comentarios con un resumen de los puntos que están bien, aquellos que debes corregir y aquellos que puedes mejorar. Luego deberás revisar todo el notebook para leer mis comentarios, los cuales estarán en rectángulos de color verde, amarillo o rojo como siguen:
#
# <div class='alert alert-block alert-success'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Muy bien! Toda la respuesta fue lograda satisfactoriamente.
# </div>
#
# <div class='alert alert-block alert-warning'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Existen detalles a mejorar. Existen recomendaciones.
# </div>
#
# <div class='alert alert-block alert-danger'>
#
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Se necesitan correcciones en el bloque. El trabajo no puede ser aceptado con comentarios en rojo sin solucionar.
# </div>
#
# Cualquier comentario que quieras agregar entre iteraciones de revisión lo puedes hacer de la siguiente manera:
#
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
#
# Mucho éxito en el proyecto!

# %% [markdown]
# ## Resumen de la revisión v1 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Hola Hilary, ¿cómo estás? Espero que todo esté bien por tu lado.
#
# Felicitaciones por completar todos los items del notebook, veo bastante trabajo a lo largo de este. En general, está todo correcto y con una buena aplicación del código necesario para lograr los objetivos. Tan solo resta que realices algunas pequeñas correcciones para el cálculo del consumo y revises cómo esto cambia el análisis de la segunda mitad, especialmente para la parte de ingreso y los tests de hipótesis. Te dejé comentarios en rojo en todas las correcciones de esta primera revisión, revísalos y realiza las modificaciones necesarias.
#
# Si tienes dudas o preguntas, me las puedes dejar en comentario azul, con gusto las responderé en la siguiente iteración.
#
# Saludos!
#
#
# </div>

# %% [markdown]
# ## Resumen de la revisión v2<a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor  v2 </b> <a class="tocSkip"></a>
#
# ¡Buen trabajo Hilary! Las últimas correcciones quedaron muy bien. Completaste todas las tareas del notebook de forma correcta, así que no tengo más observaciones que hacer. El proyecto está aprobado. Todo lo que aplicaste aquí será de gran valor en futuros análisis. ¡Mucho éxito en lo que viene!
#
# Saludos.
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# # ¿Cuál es la mejor tarifa?
#
# Trabajas como analista para el operador de telecomunicaciones Megaline. La empresa ofrece a sus clientes dos tarifas de prepago, Surf y Ultimate. El departamento comercial quiere saber cuál de las tarifas genera más ingresos para poder ajustar el presupuesto de publicidad.
#
# Vas a realizar un análisis preliminar de las tarifas basado en una selección de clientes relativamente pequeña. Tendrás los datos de 500 clientes de Megaline: quiénes son los clientes, de dónde son, qué tarifa usan, así como la cantidad de llamadas que hicieron y los mensajes de texto que enviaron en 2018. Tu trabajo es analizar el comportamiento de los clientes y determinar qué tarifa de prepago genera más ingresos.

# %% [markdown]
# [Te proporcionamos algunos comentarios para orientarte mientras completas este proyecto. Pero debes asegurarte de eliminar todos los comentarios entre corchetes antes de entregar tu proyecto.]
#
# [Antes de sumergirte en el análisis de datos, explica por tu propia cuenta el propósito del proyecto y las acciones que planeas realizar.]
#
# [Ten en cuenta que estudiar, modificar y analizar datos es un proceso iterativo. Es normal volver a los pasos anteriores y corregirlos/ampliarlos para permitir nuevos pasos.]

# %% [markdown]
# ## Inicialización

# %%
# Cargar todas las librerías


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import sqrt
from math import factorial
from scipy import stats as st

# %% [markdown]
# ## Cargar datos

# %%
# Carga los archivos de datos en diferentes DataFrames

megaline_calls_0 = pd.read_csv('data/megaline_calls (1).csv')
megaline_internet_0 = pd.read_csv('data/megaline_internet (1).csv')
megaline_messages_0 = pd.read_csv('data/megaline_messages (1).csv')
megaline_plans_0 = pd.read_csv('data/megaline_plans (1).csv')
megaline_users_0 = pd.read_csv('data/megaline_users (1).csv')

# %% [markdown]
# ## Preparar los datos

# %% [markdown]
# [Los datos para este proyecto se dividen en varias tablas. Explora cada una para tener una comprensión inicial de los datos. Si es necesario, haz las correcciones requeridas en cada tabla.]

# %% [markdown]
# ## Tarifas

# %%
# Imprime la información general/resumida sobre el DataFrame de las tarifas

print(megaline_plans_0.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_pay        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      str
# dtypes: float64(2), int64(5), str(1)
# memory usage: 260.0 bytes
# None

# %%
print (megaline_plans_0.describe())
# Out:
#        messages_included  mb_per_month_included  minutes_included  \
# count           2.000000               2.000000          2.000000
# mean          525.000000           23040.000000       1750.000000
# std           671.751442           10861.160159       1767.766953
# min            50.000000           15360.000000        500.000000
# 25%           287.500000           19200.000000       1125.000000
# 50%           525.000000           23040.000000       1750.000000
# 75%           762.500000           26880.000000       2375.000000
# max          1000.000000           30720.000000       3000.000000
#
#        usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# count         2.000000     2.00000         2.000000        2.000000
# mean         45.000000     8.50000         0.020000        0.020000
# std          35.355339     2.12132         0.014142        0.014142
# min          20.000000     7.00000         0.010000        0.010000
# ...

# %%
# Imprime una muestra de los datos para las tarifas
print (megaline_plans_0.head())
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# R= Por el momento no observo valores ausentes, ni datos no adecuados

# %% [markdown]
# ## Corregir datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %% [markdown]
# ## Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
# Bien, correcto. Se podría haber modificado el consumo de internet incluido, de mb a gb, pero no es obligatorio.
#
#
#
# </div>

# %% [markdown]
# ## Usuarios/as

# %%
# Imprime la información general/resumida sobre el DataFrame de usuarios
print(f'Información general de DataFrame Users')
print('\n')
print(megaline_users_0.info())
# Out:
# Información general de DataFrame Users
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# None

# %%
# Utilizar funcion describe
print(f'Descripción de DataFrame Users')
print('\n')
print(megaline_users_0.describe())
# Out:
# Descripción de DataFrame Users
#
#
#            user_id         age
# count   500.000000  500.000000
# mean   1249.500000   45.486000
# std     144.481833   16.972269
# min    1000.000000   18.000000
# 25%    1124.750000   30.000000
# 50%    1249.500000   46.000000
# 75%    1374.250000   61.000000
# max    1499.000000   75.000000

# %%
# Imprime una muestra de datos para usuarios
print(f'Muestra de las primeras 5 filas del DataFrame Users')
print('\n')
print(megaline_users_0.head())
# Out:
# Muestra de las primeras 5 filas del DataFrame Users
#
#
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
# 3     1003   Reynaldo    Jenkins   52                          Tulsa, OK MSA
# 4     1004    Leonila   Thompson   40        Seattle-Tacoma-Bellevue, WA MSA
#
#      reg_date      plan churn_date
# 0  2018-12-24  ultimate        NaN
# 1  2018-08-13      surf        NaN
# 2  2018-10-21      surf        NaN
# 3  2018-01-28      surf        NaN
# 4  2018-05-23      surf        NaN

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# R= Veo bien los datos se pueden leer correctamente, los valores ausentes los podemos encontrar en la columna churn_date pero esa columna cuando esta llena nos indica que se ha dejado de usar el servicio por parte del usuario y al estar vacia nos indica que sigue en uso el servicio.

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %% [markdown]
# Podemos  ivestigar si hay duplicados y valores nulos

# %%
# valores duplicados
print(megaline_users_0.duplicated().sum())
# Out:
# 0

# %%
#valores nulos NaN
print(megaline_users_0.isnull().sum())
# Out:
# user_id         0
# first_name      0
# last_name       0
# age             0
# city            0
# reg_date        0
# plan            0
# churn_date    466
# dtype: int64

# %% [markdown]
# Observamos que no hay valores duplicados y que los valores nulos corresponden a que el servicio sigue en uso

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
# Muy bien, correcta esta parte de los usuarios.
#
#
#
#
#
# </div>

# %% [markdown]
# ## Llamadas

# %%
# Imprime la información general/resumida sobre el DataFrame de las llamadas
print(f'Información general del Data Frame Calls')
print('\n')
print(megaline_calls_0.info())
# Out:
# Información general del Data Frame Calls
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB
# None

# %%
# Utililzar la funcion describe
print(f'Descripción del Data Frame Calls')
print('\n')
print(megaline_calls_0.describe())
# Out:
# Descripción del Data Frame Calls
#
#
#              user_id       duration
# count  137735.000000  137735.000000
# mean     1247.658046       6.745927
# std       139.416268       5.839241
# min      1000.000000       0.000000
# 25%      1128.000000       1.290000
# 50%      1247.000000       5.980000
# 75%      1365.000000      10.690000
# max      1499.000000      37.600000

# %%
# Imprime una muestra de datos para las llamadas

print(megaline_calls_0.head())
# Out:
#          id  user_id   call_date  duration
# 0   1000_93     1000  2018-12-27      8.52
# 1  1000_145     1000  2018-12-27     13.66
# 2  1000_247     1000  2018-12-27     14.48
# 3  1000_309     1000  2018-12-28      5.76
# 4  1000_380     1000  2018-12-30      4.22

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# R= Puedo observar que la columna id es del tipo object cuando claramente observo un numero sin embargo el guión bajo no indica una notación decimal, ni que la cifra aumenta cada tres cifras, puedo observar que el user_id se repite en varias ocaciones pero tambien puede indicar que el user_id ha realizado varias llamadas, la columna call_date la puedo leer correctamente año-mes-día, sin embargo tambien podemos intentar que se lea día-mes-año, en la duración de la llamada se puede observar un pequeño detalle que la llamada esta en sistema decimal y que normalmente se utiliza el sistema sexagesimal, sin embargo lo que tambien tenemos que hacer es redondear hacia un numero mayor cuando se ha consumido aunque sea solo un segundo.

# %% [markdown]
# Buscar informacion duplicada y valoresnulos de los Data Frames

# %% [markdown]
# megaline calls

# %%
megaline_calls_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
#utilizar la funcion decribe
print(f'Descripción del Data Frame Calls')
print('\n')

megaline_calls_0.describe()
# Out:
# Descripción del Data Frame Calls
#              user_id       duration
# count  137735.000000  137735.000000
# mean     1247.658046       6.745927
# std       139.416268       5.839241
# min      1000.000000       0.000000
# 25%      1128.000000       1.290000
# 50%      1247.000000       5.980000
# 75%      1365.000000      10.690000
# max      1499.000000      37.600000

# %% [markdown]
# podemos investigar si hay valores duplicados para eliminarlos de megaline_calls_0 ó si hay valores nulos Nan para rellenarlos con cero

# %%
#valores duplicados
print(megaline_calls_0.duplicated().sum())
# Out:
# 0

# %%
#valores nulos NaN
print(megaline_calls_0.isna().sum())
# Out:
# id           0
# user_id      0
# call_date    0
# duration     0
# dtype: int64

# %% [markdown]
# Observamos que el Data Frame megaline_calls_0 no cuentga con valores duplicados o nulos

# %% [markdown]
# megaline messages

# %%
print(f'Información general del Data Frame Messages')
print('\n')
megaline_messages_0.info()
# Out:
# Información general del Data Frame Messages
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
#Utilizar la funcion describe
print(f'Descripción del Data Frame Messages')
print('\n')
megaline_messages_0.describe()
# Out:
# Descripción del Data Frame Messages
#             user_id
# count  76051.000000
# mean    1245.972768
# std      139.843635
# min     1000.000000
# 25%     1123.000000
# 50%     1251.000000
# 75%     1362.000000
# max     1497.000000

# %% [markdown]
# Buscamos valores duplicados y valores nulos

# %%
#valores duplicados
print(megaline_messages_0.duplicated().sum())
# Out:
# 0

# %%
#valores nulos
print(megaline_messages_0.isna().sum())
# Out:
# id              0
# user_id         0
# message_date    0
# dtype: int64

# %% [markdown]
# No se encontro valores duplicados o valores nulos del DataFrame megaline messages

# %% [markdown]
# megaline internet

# %%
print(f'Información general del Data Frame Internet')
print('\n')
megaline_internet_0.info()
# Out:
# Información general del Data Frame Internet
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
#utilizar la funcion describe
print(f'Descripción del Data Frame Internet')
print('\n')
megaline_internet_0.describe()
# Out:
# Descripción del Data Frame Internet
#              user_id        mb_used
# count  104825.000000  104825.000000
# mean     1242.496361     366.713701
# std       142.053913     277.170542
# min      1000.000000       0.000000
# 25%      1122.000000     136.080000
# 50%      1236.000000     343.980000
# 75%      1367.000000     554.610000
# max      1499.000000    1693.470000

# %% [markdown]
# buscamos información duplicada y valores nulos

# %%
#valores duplicados
print(megaline_internet_0.duplicated().sum())
# Out:
# 0

# %%
#valores nulos NaN
print(megaline_internet_0.isna().sum())
# Out:
# id              0
# user_id         0
# session_date    0
# mb_used         0
# dtype: int64

# %% [markdown]
# No se encontraron valores duplicados ni valores nulos

# %% [markdown]
# En esta parte me permiti recuperar informacion de los dataframes que faltaban
# de los Data Frames Calls, Messages e internet, para observar la cantidad de información con laque cuenta cada uno

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %%
# Redondea la duración de la llamada hacia arriba al minuto más cercano
megaline_calls_0['duration'] = np.ceil(megaline_calls_0['duration'])
megaline_calls_0['duration'] = megaline_calls_0['duration'].astype(int)

# %%
#imprimimos una muestra de la columna duration
#del Data Frame megaline_calls
print(megaline_calls_0['duration'].head())
# Out:
# 0     9
# 1    14
# 2    15
# 3     6
# 4     5
# Name: duration, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, la conversión de la duración a duración que se factura está correcta
#
# </div>

# %% [markdown]
# Aqui con la función ceil redondeamos un numero hacia arriba

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %%
# Cambiar nombre a la columna duration por duration_min
megaline_calls_0 = megaline_calls_0.rename(columns={'duration': 'duration_min'})
print (megaline_calls_0.columns)
# Out:
# Index(['id', 'user_id', 'call_date', 'duration_min'], dtype='object')

# %% [markdown]
# Como nos han indicado hemos convertido los segundos a la unidad mayor minutos

# %% [markdown]
# ## Mensajes

# %%
# Imprime la información general/resumida sobre el DataFrame de los mensajes
print(f'Información general del Data Frame Messages')
print('\n')
megaline_messages_0.info()
# Out:
# Información general del Data Frame Messages
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
megaline_messages_0.shape
# Out:
# (76051, 3)

# %%
# Imprime una muestra de datos para los mensajes

megaline_messages_0.head()
# Out:
#          id  user_id message_date
# 0  1000_125     1000   2018-12-27
# 1  1000_160     1000   2018-12-31
# 2  1000_223     1000   2018-12-31
# 3  1000_251     1000   2018-12-27
# 4  1000_255     1000   2018-12-26

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# El Data Frame se lee correctamente tiene todos los datos completos.

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
#
# Ok, correcto
#
# </div>

# %% [markdown]
# ## Internet

# %%
# Imprime la información general/resumida sobre el DataFrame de internet
print(f'Información general del Data Frame Internet')
print('\n')
print (megaline_internet_0.info())
# Out:
# Información general del Data Frame Internet
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB
# None

# %%
# Imprime una muestra de datos para el tráfico de internet

print (megaline_internet_0.head())
# Out:
#          id  user_id session_date  mb_used
# 0   1000_13     1000   2018-12-29    89.86
# 1  1000_204     1000   2018-12-31     0.00
# 2  1000_379     1000   2018-12-28   660.40
# 3  1000_413     1000   2018-12-26   270.99
# 4  1000_442     1000   2018-12-27   880.22

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %%
#cambiar nombre a la columna mb_used por mb_cons
megaline_internet_0 = megaline_internet_0.rename(columns={'mb_used': 'mb_cons'})
print (megaline_internet_0.columns)
# Out:
# Index(['id', 'user_id', 'session_date', 'mb_cons'], dtype='object')

# %%
#Redondear los megabytes en una unidad mayor (Quite esta parte)
#megaline_internet_0['mb_cons'] = np.ceil(megaline_internet_0['mb_cons'])
#Este codigo de arriba no va
#convertimos a entero
megaline_internet_0['mb_cons'] = megaline_internet_0['mb_cons'].astype(int)
megaline_internet_0['mb_cons'].head()
# Out:
# 0     89
# 1      0
# 2    660
# 3    270
# 4    880
# Name: mb_cons, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
#
# Esta modificación para el consumo de internet es incorrecta, en esta parte no se deben aproximar hacia arriba los consumos, ya que Megaline no aproxima cada sesión, sino que el consumo mensual de internet.
#
# Más adelante, cuando agrupes por usuario y mes, y ya hayas convertido a gb, recién ahí se debe aproximar hacia arriba.
#
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante: Procedí a eliminar esa parte donde redondeo y la deje solo en texto </b> <a class='tocSkip'></a>
# </div>

# %%
print (megaline_internet_0['mb_cons'].head())
# Out:
# 0     89
# 1      0
# 2    660
# 3    270
# 4    880
# Name: mb_cons, dtype: int64

# %%
print (megaline_internet_0['mb_cons'].info())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_121/1629387773.py in ?()
# ----> 1 print (megaline_internet_0['mb_cons'].info())
#
# /.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'info'

# %% [markdown]
# Lo hemos convertido al tipo entero

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %% [markdown]
# Como nos lo han indicado hemos convertido los megabytes a gigabytes

# %% [markdown]
# ## Estudiar las condiciones de las tarifas

# %% [markdown]
# [Es sumamente importante entender cómo funcionan las tarifas, cómo se les cobra a los usuarios en función de su plan de suscripción. Así que te sugerimos imprimir la información de la tarifa para ver una vez más sus condiciones.]

# %%
# Imprime las condiciones de la tarifa y asegúrate de que te quedan claras

print (megaline_plans_0)
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %%
megaline_plans_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_pay        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# ## Agregar datos por usuario
#
# [Ahora que los datos están limpios, agrega los datos por usuario y por periodo para que solo haya un registro por usuario y por periodo. Esto facilitará mucho el análisis posterior.]

# %%
#convertimos al formato datetime
megaline_calls_0['call_date'] = pd.to_datetime(megaline_calls_0['call_date'], format='%Y-%m-%d')
print((megaline_calls_0['call_date'].head()))
# Out:
# 0   2018-12-27
# 1   2018-12-27
# 2   2018-12-27
# 3   2018-12-28
# 4   2018-12-30
# Name: call_date, dtype: datetime64[ns]

# %%
# Calcula el número de llamadas hechas por cada usuario al mes. Guarda el resultado.
megaline_calls_0['month'] = megaline_calls_0['call_date'].dt.month
calls_per_month = megaline_calls_0.groupby(['user_id', 'month']).size().reset_index(name='calls_cons')
print(calls_per_month.head())
# Out:
#    user_id  month  calls_cons
# 0     1000     12          16
# 1     1001      8          27
# 2     1001      9          49
# 3     1001     10          65
# 4     1001     11          64

# %% [markdown]
# En los ejercicios anteriores podemos ver
# el número de llamadas hechas por cada usuario al mes.

# %% [markdown]
# En ej ejercicio anterior creamos una columna con el número de llamadas hechas por cada usuario al mes

# %%
# Calcula la cantidad de minutos usados por cada usuario al mes. Guarda el resultado.
print('\n')
print(f'Agrupación por usurio, mes y minutos consumidos')
print('\n')
megaline_calls_0['duration_min'] = megaline_calls_0['duration_min'].astype(int)
minutes_per_month = megaline_calls_0.groupby(['user_id', 'month'])['duration_min'].sum().reset_index(name='minutes_cons')
print(minutes_per_month.head())
# Out:
# Agrupación por usurio, mes y minutos consumidos
#
#
#    user_id  month  minutes_cons
# 0     1000     12           124
# 1     1001      8           182
# 2     1001      9           315
# 3     1001     10           393
# 4     1001     11           426

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Muy bien, correcto el cálculo del consumo mensual de llamadas para cada usuario.
#
#
# </div>

# %% [markdown]
# En el ejercicio anterior se obtuvo la cantidad de minutos usados por cada usuario al mes.

# %% [markdown]
# En el ejercicio anterior creamos una columna con la cantidad de minutos usados por cada usuario al mes.

# %%
# Calcula el número de mensajes enviados por cada usuario al mes. Guarda el resultado.
print('\n')
print(f'Agrupación por usurio, mes y mensajes consumidos')
print('\n')

megaline_messages_0['message_date'] = pd.to_datetime(megaline_messages_0['message_date'], format='%Y-%m-%d')
megaline_messages_0['month'] = megaline_messages_0['message_date'].dt.month
messages_per_month = megaline_messages_0.groupby(['user_id', 'month']).size().reset_index(name='messages_cons')
print(messages_per_month.head())
# Out:
# Agrupación por usurio, mes y mensajes consumidos
#
#
#    user_id  month  messages_cons
# 0     1000     12             11
# 1     1001      8             30
# 2     1001      9             44
# 3     1001     10             53
# 4     1001     11             36

# %% [markdown]
# En el ejercicio anterior calculamos el número de mensajes enviados por cada usuario al mes.

# %% [markdown]
# En el ejercicio anteriro cremos una columna de el número de mensajes enviados por cada usuario al mes.

# %%
# Calcula el volumen del tráfico de Internet usado por cada usuario al mes. Guarda el resultado.
print('\n')
print(f'Agrupación por usurio, mes y mb consumidos')
print('\n')
megaline_internet_0['session_date'] = pd.to_datetime(megaline_internet_0['session_date'], format='%Y-%m-%d')
megaline_internet_0['month'] = megaline_internet_0['session_date'].dt.month
megaline_internet_0['mb_cons'] = megaline_internet_0['mb_cons'].astype(int)
mb_used_per_month = megaline_internet_0.groupby(['user_id', 'month'])['mb_cons'].sum().reset_index(name='mb_cons')
print(mb_used_per_month.head())
# Out:
# Agrupación por usurio, mes y mb consumidos
#
#
#    user_id  month  mb_cons
# 0     1000     12     1899
# 1     1001      8     6908
# 2     1001      9    13294
# 3     1001     10    22308
# 4     1001     11    18477

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien, correcto el cálculo de consumo de mensajes e internet. Luego, el internet se debe convertir a gb y aproximarse hacia arriba.
#
# </div>

# %% [markdown]
#  En el ejercicio anterior obtuvimos tráfico de Internet usado por cada usuario al mes.

# %% [markdown]
#  En el ejercicio anterior creamos una columna del tráfico de Internet usado por cada usuario al mes.

# %%
#imprimimos las columnas del Data Frame megaline_internet_0
megaline_internet_0.columns
# Out:
# Index(['id', 'user_id', 'session_date', 'mb_cons', 'month'], dtype='object')

# %% [markdown]
# [Junta los datos agregados en un DataFrame para que haya un registro que represente lo que consumió un usuario único en un mes determinado.]

# %%
# Mostramos una muestra de las primeras 5 filas del DataFrame Calls

megaline_calls_0.head()
# Out:
#          id  user_id  call_date  duration_min  month
# 0   1000_93     1000 2018-12-27             9     12
# 1  1000_145     1000 2018-12-27            14     12
# 2  1000_247     1000 2018-12-27            15     12
# 3  1000_309     1000 2018-12-28             6     12
# 4  1000_380     1000 2018-12-30             5     12

# %%
# Fusiona los datos de llamadas, minutos, con base en user_id y month
megaline_merge_calls_minutes = calls_per_month.merge(minutes_per_month, on=['user_id', 'month'], how='outer') #cambie how='left' por 'outer'
print(megaline_merge_calls_minutes.head())
# Out:
#    user_id  month  calls_cons  minutes_cons
# 0     1000     12          16           124
# 1     1001      8          27           182
# 2     1001      9          49           315
# 3     1001     10          65           393
# 4     1001     11          64           426

# %%
# Fusiona los datos de llamadas, minutos, mensajes con base en user_id y month
megaline_merge_calls_minutes_messages = megaline_merge_calls_minutes.merge(messages_per_month, on=['user_id', 'month'], how='outer') #cambie how='left' por 'outer'
print(megaline_merge_calls_minutes_messages.head())
# Out:
#    user_id  month  calls_cons  minutes_cons  messages_cons
# 0     1000     12        16.0         124.0           11.0
# 1     1001      8        27.0         182.0           30.0
# 2     1001      9        49.0         315.0           44.0
# 3     1001     10        65.0         393.0           53.0
# 4     1001     11        64.0         426.0           36.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Para esta parte debes usar merges de tipo outer (usa el parámetro `how='outer'` dentro de merge). Si no, se pierden datos, te dejo un ejemplo.
#
# Supongamos que hacemos el merge entre los dataframes:
#
#     df_mensajes
#
# | user_id | month | mensajes |
# |---------|-------|----------|
# |    1    |   2   |    10    |
# |    2    |   2   |     4    |
# |    3    |   3   |     5    |
# |    3    |   4   |     5    |
#
#     df_llamadas
#
# | user_id | month | minutos_llamadas |
# |----|-------|------------------|
# | 2  |   2   |       120        |
# | 3  |   4   |       200        |
# | 4  |   5   |      1000        |
#
# Nota que tenemos usuarios que solo realizaron mensajes (el usuario 1), solo realizaron llamadas (el usuario 4) y otro que un mes realizo mensajes pero no llamadas y al otro mes realizo llamadas solamente (el usuario 3).
#
# Al hacer un `merge` por defecto en pandas (es decir, sin especificar el tipo de merge), se utiliza el tipo **inner join**. Esto significa que solo se incluirán las filas cuyos valores de las columnas usadas como llave (`user_id` y `month` en este caso) esté presente en **ambos** DataFrames.
#
#
#
# Si hacemos `df_mensajes.merge(df_llamadas, on=['user_id', 'month'])` o también `pd.merge(df_mensajes, df_llamadas, on=['user_id', 'month'])`, obtendremos:
#
#
# | user_id | month | mensajes | minutos_llamadas |
# |---------|-------|----------|------------------|
# |    2    |   2   |     4    |       120        |
# |    3    |   4   |     5    |       200        |
#
#
# Solo se conservan las filas donde coinciden tanto `user_id` como `month` entre las dos tablas (usuarios 2 en mes 2 y usuario 3 en mes 4). Por lo tanto, el consumo que tenemos está incompleto, ya que los otros casos que no vienen en este resultado deberían conservarse para el cálculo de cuánto se les cobrará.
#
# Si en cambio usamos `how='outer'`, se conserva **toda la información** de ambas tablas, y se rellenan los valores faltantes con `NaN`. El resultado de `df_mensajes.merge(df_llamadas, on=['user_id', 'month'], how='outer')` o también `pd.merge(df_mensajes, df_llamadas, on=['user_id', 'month'], how='outer')` es
#
#
# | user_id | month | mensajes | minutos_llamadas |
# |---------|-------|----------|------------------|
# |    1    |   2   |    10    |       NaN        |
# |    2    |   2   |     4    |       120        |
# |    3    |   3   |     5    |       NaN        |
# |    3    |   4   |     5    |       200        |
# |    4    |   5   |   NaN    |      1000        |
#
# Se incluyen todos los registros de ambos DataFrames. Cuando no hay coincidencias en las claves combinadas (`user_id` y `month`), los campos faltantes se completan con `NaN`. Esto permite tener todo el consumo.
#
# Como conclusión:
#
# - **`merge()` por defecto (`inner`)**: Devuelve solo las filas con coincidencia exacta entre los DataFrames.
# - **`merge(..., how='outer')`**: Devuelve todas las filas de ambos DataFrames, incluyendo `NaN` donde no hay coincidencias.
#
# Este tipo de operación es útil para ver tanto los datos coincidentes como los que están **solo en una de las tablas**, por ejemplo, para detectar información faltante o comparar actividad entre distintas fuentes. En este caso nos sirve para incluir todo el consumo y hacer el cálculo del cobro completo.
#
# Luego de usar este tipo de merge, habrán algunos nulos en las columnas de consumo, lo cual significa que ese usuario, en ese mes, no realizó ese consumo. Aplica `fillna(0)` para reemplazarlos por 0, así no tendrás problemas para el cálculo del ingreso total.
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Re: Muchas gracias por las observaciones realizadas procededere a corregirlo </b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor v2    </b> <a class="tocSkip"></a>
#
# Correcto el uso del merge tipo outer, esto evita que se pierdan datos de usuarios.
#
# </div>

# %%
#visualizamos las primeras 5 filas del DataFrame megaline_users_0
print(megaline_users_0.head())
# Out:
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
# 3     1003   Reynaldo    Jenkins   52                          Tulsa, OK MSA
# 4     1004    Leonila   Thompson   40        Seattle-Tacoma-Bellevue, WA MSA
#
#      reg_date      plan churn_date
# 0  2018-12-24  ultimate        NaN
# 1  2018-08-13      surf        NaN
# 2  2018-10-21      surf        NaN
# 3  2018-01-28      surf        NaN
# 4  2018-05-23      surf        NaN

# %%
#Fusiona los datos de llamadas, minutos, mensajes e Internet con base en user_id y month
megaline_merge_calls_minutes_messages_internet = megaline_merge_calls_minutes_messages.merge(mb_used_per_month, on=['user_id', 'month'], how='outer')
#cambie how='left' por 'outer'
print(megaline_merge_calls_minutes_messages_internet.head())
# Out:
#    user_id  month  calls_cons  minutes_cons  messages_cons  mb_cons
# 0     1000     12        16.0         124.0           11.0   1899.0
# 1     1001      8        27.0         182.0           30.0   6908.0
# 2     1001      9        49.0         315.0           44.0  13294.0
# 3     1001     10        65.0         393.0           53.0  22308.0
# 4     1001     11        64.0         426.0           36.0  18477.0

# %% [markdown]
# En esta parte unimos los DataFrames de llamada, minutos, mensajes y gb  mediante la funcion merge

# %%
megaline_users = megaline_users_0.groupby('user_id')['plan'].first().reset_index(name='plan_name')
print(megaline_users.head())
# Out:
#    user_id plan_name
# 0     1000  ultimate
# 1     1001      surf
# 2     1002      surf
# 3     1003      surf
# 4     1004      surf

# %%
#Añadir información de la Tarifa
#Unir DataFrames usuario, tarifas, llamadas, minutos, mensajes, internet, tarifas

meg_mer_pl_call_min_msg_int = megaline_users.merge(megaline_merge_calls_minutes_messages_internet, on='user_id', how='outer')
#cambie how='left' por 'outer'

print(meg_mer_pl_call_min_msg_int.head())
# Out:
#    user_id plan_name  month  calls_cons  minutes_cons  messages_cons  mb_cons
# 0     1000  ultimate   12.0        16.0         124.0           11.0   1899.0
# 1     1001      surf    8.0        27.0         182.0           30.0   6908.0
# 2     1001      surf    9.0        49.0         315.0           44.0  13294.0
# 3     1001      surf   10.0        65.0         393.0           53.0  22308.0
# 4     1001      surf   11.0        64.0         426.0           36.0  18477.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien, en esta parte basta con el uso de left ya que la data de consumo de usuarios ya debería estar completa.
#
# </div>

# %% [markdown]
# [Calcula los ingresos mensuales por usuario (resta el límite del paquete gratuito del número total de llamadas, mensajes de texto y datos; multiplica el resultado por el valor del plan de llamadas; añade la tarifa mensual en función del plan de llamadas). Nota: Dadas las condiciones del plan, ¡esto podría no ser tan trivial como un par de líneas! Así que no pasa nada si dedicas algo de tiempo a ello.]

# %%
#Revisar informacion de los planes
print(megaline_plans_0.head())
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# Observamos que la cantidad que nos indican es correcta para la cantidad de mb por mes incluidos en cada plan para obtener GB debemos dividir entre 1024 mb = 1 GB

# %% [markdown]
# En los ejercicios anteriores se cambio la cantidad de mb incluidos por mes para cada plan

# %%
#Unir Data Frames megaline plans con meg_mer_pl_call_min_msg_int
dfcompilated = meg_mer_pl_call_min_msg_int.merge(megaline_plans_0, on='plan_name', how='outer') #cambie how='left' por 'outer'
print(dfcompilated.head())
# Out:
#    user_id plan_name  month  calls_cons  minutes_cons  messages_cons  mb_cons  \
# 0     1000  ultimate   12.0        16.0         124.0           11.0   1899.0
# 1     1006  ultimate   11.0         2.0          10.0           15.0   2066.0
# 2     1006  ultimate   12.0         9.0          59.0          139.0  32085.0
# 3     1008  ultimate   10.0        71.0         476.0           21.0  17083.0
# 4     1008  ultimate   11.0        63.0         446.0           37.0  23652.0
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# ...

# %% [markdown]
# Me dice calcular el ingreso mensual por usuario y en las instrucciones dice que por llamadas pero en realidad no me indican un parametro para llamadas pero si me proporcionan informacion por minutos por lo cual procedo a trabajar con esa información

# %%
import numpy as np

# Prepare the DataFrame: fill NaNs and convert types before applying the function
columns_to_fill_and_convert = ['month', 'calls_cons', 'minutes_cons', 'messages_cons', 'mb_cons']
for col in columns_to_fill_and_convert:
    if col in dfcompilated.columns:
        dfcompilated[col] = dfcompilated[col].fillna(0).astype(int)
print(dfcompilated.head())
# Out:
#    user_id plan_name  month  calls_cons  minutes_cons  messages_cons  mb_cons  \
# 0     1000  ultimate     12          16           124             11     1899
# 1     1006  ultimate     11           2            10             15     2066
# 2     1006  ultimate     12           9            59            139    32085
# 3     1008  ultimate     10          71           476             21    17083
# 4     1008  ultimate     11          63           446             37    23652
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
#
# Muy bien, correcto el relleno de nulos
#
#
# </div>

# %%
#Calcular el ingreso mensual por usuario
#calcular el ingreso mensual sumandole los excedentes del plan
def calculate_monthly_revenue(row):
  """calcular el ingreso total basado en excedentes del plan"""
  #ingreso base
  revenue = row['usd_monthly_pay']

  #Exceso de minutos
  if row['minutes_cons'] > row['minutes_included']:
      revenue += (row['minutes_cons'] - row['minutes_included']) * row['usd_per_minute']

  #Exceso de mensajes consumidos
  if row['messages_cons'] > row['messages_included']:
      revenue += (row['messages_cons'] - row['messages_included']) * row['usd_per_message']

  #Exceso de GB consumidos y redondearlos a la unidad superior de GB
  if row['mb_cons'] > row['mb_per_month_included']:
      gb_extra = np.ceil((row['mb_cons'] - row['mb_per_month_included']) / 1024) # 1.1 -> 2 | 1024MB -> 1GB
      revenue += gb_extra * row['usd_per_gb']

  return revenue

dfcompilated['monthly_revenue'] = dfcompilated.apply(calculate_monthly_revenue, axis=1)
print(dfcompilated.head())
# Out:
#    user_id plan_name  month  calls_cons  minutes_cons  messages_cons  mb_cons  \
# 0     1000  ultimate     12          16           124             11     1899
# 1     1006  ultimate     11           2            10             15     2066
# 2     1006  ultimate     12           9            59            139    32085
# 3     1008  ultimate     10          71           476             21    17083
# 4     1008  ultimate     11          63           446             37    23652
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# La idea del cálculo del revenue mensual va bien, pero se requiere que la data esté completa (el tipo de merge debe ser outer). Con eso corregido se tendrá el ingreso completo
#
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante. Con las observaciones realizadas lo he corregido</b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor    v2</b> <a class="tocSkip"></a>
#
#
# Muy buen trabajo! El cálculo del revenue mensual por usuario está correcto
#
# </div>

# %%
# Calcula el ingreso mensual para cada usuario
# Visualizar las primeras 5 filas de la columnas

print(dfcompilated.head())
# Out:
#    user_id plan_name  month  calls_cons  minutes_cons  messages_cons  mb_cons  \
# 0     1000  ultimate     12          16           124             11     1899
# 1     1006  ultimate     11           2            10             15     2066
# 2     1006  ultimate     12           9            59            139    32085
# 3     1008  ultimate     10          71           476             21    17083
# 4     1008  ultimate     11          63           446             37    23652
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute  \
# ...

# %%
# Buscar informacion relevante del nuevo Data Frame
print('Informacion relevante del nuevo Data Frame')
print('\n')
dfcompilated.info
# Out:
# Informacion relevante del nuevo Data Frame
# <bound method DataFrame.info of       user_id plan_name  month  calls_cons  minutes_cons  messages_cons  \
# 0        1000  ultimate     12          16           124             11
# 1        1006  ultimate     11           2            10             15
# 2        1006  ultimate     12           9            59            139
# 3        1008  ultimate     10          71           476             21
# 4        1008  ultimate     11          63           446             37
# ...       ...       ...    ...         ...           ...            ...
# 2298     1498      surf     12          39           339              0
# 2299     1499      surf      9          41           346              0
# 2300     1499      surf     10          53           385              0
# 2301     1499      surf     11          45           308              0
# 2302     1499      surf     12          65           496              0
#
# ...

# %%
print('Descripción del nuevo Data Frame')
print('\n')
dfcompilated.describe()
# Out:
# Descripción del nuevo Data Frame
#            user_id        month   calls_cons  minutes_cons  messages_cons  \
# count  2303.000000  2303.000000  2303.000000   2303.000000    2303.000000
# mean   1246.214937     9.132870    59.806774    427.419453      33.022579
# std     143.044136     2.562964    32.572548    237.490294      34.065907
# min    1000.000000     0.000000     0.000000      0.000000       0.000000
# 25%    1122.000000     8.000000    38.000000    262.500000       3.000000
# 50%    1245.000000    10.000000    60.000000    424.000000      25.000000
# 75%    1368.000000    11.000000    79.000000    571.500000      51.000000
# max    1499.000000    12.000000   205.000000   1510.000000     266.000000
#
#             mb_cons  messages_included  mb_per_month_included  \
# count   2303.000000         2303.00000            2303.000000
# mean   16672.003908          348.65393           20188.762484
# std     8018.191097          441.14801            7132.666777
# ...

# %% [markdown]
# ## Estudia el comportamiento de usuario

# %% [markdown]
# [Calcula algunas estadísticas descriptivas para los datos agregados y fusionados que nos sean útiles y que muestren un panorama general captado por los datos. Dibuja gráficos útiles para facilitar la comprensión. Dado que la tarea principal es comparar las tarifas y decidir cuál es más rentable, las estadísticas y gráficas deben calcularse por tarifa.]
#
# [En los comentarios hallarás pistas relevantes para las llamadas, pero no las hay para los mensajes e Internet. Sin embargo, el principio del estudio estadístico que se aplica para ellos es el mismo que para las llamadas.]

# %% [markdown]
# ### Llamadas

# %%
# Calculate the average minutes per month for each plan
avg_minutes_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['minutes_cons'].mean().reset_index()

# Now, we can filter this result to get the average for each plan separately
minprom_llamxmes_plansurf = avg_minutes_per_month_per_plan[avg_minutes_per_month_per_plan['plan_name'] == 'surf']
minprom_llamxmes_planult = avg_minutes_per_month_per_plan[avg_minutes_per_month_per_plan['plan_name'] == 'ultimate']
print(f'Promedio de minutos consumidos por mes de ambso planes')
print('\n')
print(f'Promedio de minutos consumidos por mes del plan surf')
print('\n')
print(minprom_llamxmes_plansurf)
print('\n')
print(f'Promedio de minutos consumidos por mes del plan ultimate')
print('\n')
print(minprom_llamxmes_planult)
# Out:
# Promedio de minutos consumidos por mes de ambso planes
#
#
# Promedio de minutos consumidos por mes del plan surf
#
#
#     month plan_name  minutes_cons
# 0       0      surf      0.000000
# 2       1      surf    203.000000
# 4       2      surf    297.000000
# 6       3      surf    330.000000
# 8       4      surf    351.540000
# 10      5      surf    399.584416
# 12      6      surf    431.298969
# 14      7      surf    449.983471
# 16      8      surf    410.111111
# 18      9      surf    414.226804
# 20     10      surf    429.729958
# 22     11      surf    423.325088
# 24     12      surf    473.836478
#
#
# Promedio de minutos consumidos por mes del plan ultimate
#
#
#     month plan_name  minutes_cons
# 1       0  ultimate      0.000000
# 3       1  ultimate    193.500000
# 5       2  ultimate    403.142857
# 7       3  ultimate    304.250000
# 9       4  ultimate    336.857143
# 11      5  ultimate    406.241379
# 13      6  ultimate    370.957447
# ...

# %%
#traza un grafico de barras para visualizarla
import matplotlib.pyplot as plt

# Plot for Surf plan
ax = minprom_llamxmes_plansurf.plot(x='month',
                               y='minutes_cons', # Corrected y-axis: use the actual column name
                               kind='bar',
                               title='Average Minutes Per Month for Surf and Ultimate Plans',
                               xlabel='Month',
                               ylabel='Average Minutes',
                               color='skyblue',
                               figsize=(7, 4)
                               )

# Plot for Ultimate plan on the same axes
minprom_llamxmes_planult.plot(x='month',
                              y='minutes_cons', # Corrected y-axis: use the actual column name
                              kind='bar',
                              ax=ax, # Plot on the same axes as the first plot
                              alpha=0.7, # Transparency for overlay
                              color='grey'
                              )

plt.legend(['Surf', 'Ultimate'])
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
print(f'Grafico de minutos promedio en llamadas por mes del plan surf y ultimate')
plt.show()
# Out:
# Grafico de minutos promedio en llamadas por mes del plan surf y ultimate

# %% [markdown]
# Observaciones sobre el promedio de minutos consumidos por mes: Promedio general de minutos consumidos por mes (meanmegcallmin): El gráfico sugiere que, en promedio, el consumo de minutos no varía drásticamente de un mes a otro a lo largo del año, aunque hay una ligera tendencia al aumento hacia el final del año.
#
#
# Promedio de minutos para el plan Surf (minprom_llamxmes_plansurf): Los usuarios del plan Surf muestran un rango de consumo promedio mensual que empieza bajo y aumenta progresivamente. El gráfico de barras sugiere que hay una variabilidad considerable en el promedio mensual, con algunos meses mostrando un promedio de minutos más alto, muestra picos de promedio un poco mas altos.
#
# Promedio de minutos para el plan Ultimate (minprom_llamxmes_planult): De manera similar, los usuarios de Ultimate también muestran un consumo promedio mensual que aumenta a lo largo del año. Comparando con el plan Surf, la distribución de sus promedios mensuales parece estar en un rango similar, aunque el plan Ultimate tiende a tener promedios ligeramente más altos en algunos meses, especialmente a finales de año y un pico en febreo que se podria asociar a un mes asociado al día festivo del amor y la amistad.

# %%
import matplotlib.pyplot as plt

# Filter dfcompilated for 'surf' and 'ultimate' plans
surf_minutes = dfcompilated[dfcompilated['plan_name'] == 'surf']['minutes_cons']
ultimate_minutes = dfcompilated[dfcompilated['plan_name'] == 'ultimate']['minutes_cons']

# Create a figure and axes
fig, ax = plt.subplots(figsize=(7, 4))

# Plot histograms for each plan
surf_minutes.hist(ax=ax, bins=12, alpha=0.7, color='skyblue', label='Surf')
ultimate_minutes.hist(ax=ax, bins=12, alpha=0.7, color='grey', label='Ultimate')

ax.set_xlabel('Total Monthly Minutes Consumed')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Total Monthly Minutes Consumed by Plan')
ax.legend()
plt.tight_layout()
print('Histograma del total de minutos consumidos por mes del plan surf y ultimate')
print('\n')
plt.show()
# Out:
# Histograma del total de minutos consumidos por mes del plan surf y ultimate

# %% [markdown]
# En el histograma de los minutos totales consumidospor mes del plan surf y ultimate se observa una mayor densidad para el plan surf y una menor densidad para el plan ultimate, con una media cerca de los 350 min para el plan surf y de 140 minutos para el plan ultimate por lo que es evidente que el plan ultimate no es tan consumido como el plan surf y que su uso es muy por debajo de los beneficios respecto a minutos que el plan ofrece.

# %% [markdown]
# [Calcula la media y la variable de la duración de las llamadas para averiguar si los usuarios de los distintos planes se comportan de forma diferente al realizar sus llamadas.]

# %%
# Calcula la media y la varianza de la duración mensual de llamadas.

# %%
#Varianza en los minutos por mes de ambos planes surf y ultimate

variancemegcallmin = dfcompilated.groupby(['month', 'plan_name'])['minutes_cons'].var()
variancemegcallminplansurf = variancemegcallmin[variancemegcallmin.index.get_level_values('plan_name') == 'surf']
variancemegcallminplanult = variancemegcallmin[variancemegcallmin.index.get_level_values('plan_name') == 'ultimate']
print(f'Varianza de minutos consumidos por mes del plan surf')
print('\n')
print(variancemegcallminplansurf)
print('\n')
print(f'Varianza de minutos consumidos por mes del plan ultimate')
print('\n')
print(variancemegcallminplanult)
print('\n')
# Out:
# Varianza de minutos consumidos por mes del plan surf
#
#
# month  plan_name
# 0      surf             0.000000
# 1      surf         15842.000000
# 2      surf         52226.500000
# 3      surf         35809.363636
# 4      surf         50866.743265
# 5      surf         59754.219754
# 6      surf         45592.628436
# 7      surf         61005.099725
# 8      surf         54344.645963
# 9      surf         46595.958656
# 10     surf         52278.664056
# 11     surf         51607.021602
# 12     surf         63629.518918
# Name: minutes_cons, dtype: float64
#
#
# Varianza de minutos consumidos por mes del plan ultimate
#
#
# month  plan_name
# 0      ultimate         0.000000
# 1      ultimate     16572.333333
# 2      ultimate     76889.476190
# 3      ultimate     61984.931818
# 4      ultimate     34888.928571
# 5      ultimate     43841.046798
# 6      ultimate     42503.563367
# 7      ultimate     72563.374635
# 8      ultimate     53645.506640
# ...

# %%
# Ambos boxplot de mensajes por mes del plan surf y plan ultimate

import matplotlib.pyplot as plt
import numpy as np



# Ensure dfcompilated is available and messages_cons column is prepared.
# Assuming dfcompilated is already defined from previous steps and 'messages_cons' is correctly processed.

# Re-define messages_per_month_per_plan, msgxmes_plansurf, and msgxmes_planult
#messages_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].sum().reset_index()


# Prepare data for box plots
data_to_plot = [
    variancemegcallminplansurf,
    variancemegcallminplanult
]

labels = ['Plan Surf', 'Plan Ultimate']

fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot(data_to_plot, vert=False, labels=labels, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'),
           whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'),
           flierprops=dict(marker='o', markerfacecolor='red', markersize=6,
                           linestyle='none'))

ax.set_xlabel('Variance de minutos por mes consumidos')
ax.set_title('Distribución de Minutos Mensuales Consumidos por Plan')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
print(f'Grafico de caja de la varianza de minutos\n consumidos por mes del plan surf y ultimate')
print('\n')

plt.show()
# Out:
# Grafico de caja de la varianza de minutos
#  consumidos por mes del plan surf y ultimate

# %% [markdown]
# Varianza general de minutos consumidos por mes: El gráfico de caja para la varianza general indica una dispersión considerable en la variabilidad del consumo de minutos a lo largo de los meses. Esto significa que la consistencia en el uso de minutos cambia significativamente de un mes a otro, con algunos meses mostrando una mayor heterogeneidad en el comportamiento de los usuarios.
#
# Las variables `variancemegcallminplansurf` y `variancemegcallminplanult` representan la varianza del promedio de minutos mensuales consumidos para los planes Surf y Ultimate, respectivamente. Una mayor varianza,varianza del plan Ultimate (varianceminultimate):indica una mayor fluctuación en el consumo promedio mensual de minutos a lo largo del tiempo, mientras que una menor varianza, Varianza del plan Surf (varianceminsurf):sugiere un uso promedio más constante.

# %%
### Calculate the measures of statistical tendency msg per month for each plan
#calcular la desviacion estandart
desv_est_min_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].std().reset_index()

#Ahora filtraremos por separado cada plan
des_est_minxmes_plansurf = desv_est_min_per_month_per_plan[desv_est_min_per_month_per_plan['plan_name'] == 'surf']
des_est_minxmes_planult = desv_est_min_per_month_per_plan[desv_est_min_per_month_per_plan['plan_name'] == 'ultimate']
print(f'Desviacion estandar de mensajes consumidos\n de ambos planes')
print('\n')
print('Desviacion estandar de minutos consumidos\n plan surf')
print('\n')
print(des_est_minxmes_plansurf)
print('\n')
print('Desviacion estandar de minutos consumidos\n plan ultimate')
print('\n')
print(des_est_minxmes_planult)
# Out:
# Desviacion estandar de mensajes consumidos
#  de ambos planes
#
#
# Desviacion estandar de minutos consumidos
#  plan surf
#
#
#     month plan_name  messages_cons
# 0       0      surf       0.000000
# 2       1      surf      14.849242
# 4       2      surf      19.646883
# 6       3      surf      18.616262
# 8       4      surf      22.396246
# 10      5      surf      29.106652
# 12      6      surf      30.247646
# 14      7      surf      30.395979
# 16      8      surf      32.086064
# 18      9      surf      31.683268
# 20     10      surf      35.713663
# 22     11      surf      32.639608
# 24     12      surf      38.185843
#
#
# Desviacion estandar de minutos consumidos
#  plan ultimate
#
#
#     month plan_name  messages_cons
# 1       0  ultimate       0.000000
# 3       1  ultimate      17.710637
# 5       2  ultimate      21.869744
# 7       3  ultimate      25.580977
# 9       4  ultimate      23.326972
# 11      5  ultimate      36.018195
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure dfcompilated is available and messages_cons column is prepared.
# Assuming dfcompilated is already defined from previous steps and 'min_cons' is correctly processed.

# Re-define messages_per_month_per_plan, msgxmes_plansurf, and msgxmes_planult

desv_est_min_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['minutes_cons'].std().reset_index()

#Ahora filtraremos por separado cada plan
des_est_minxmes_plansurf = desv_est_min_per_month_per_plan[desv_est_min_per_month_per_plan['plan_name'] == 'surf']
des_est_minxmes_planult = desv_est_min_per_month_per_plan[desv_est_min_per_month_per_plan['plan_name'] == 'ultimate']
# Prepare data for box plots
data_to_plot = [
    des_est_minxmes_plansurf['minutes_cons'],
    des_est_minxmes_planult['minutes_cons']
]

labels = ['Plan Surf', 'Plan Ultimate']

fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot(data_to_plot, vert=False, labels=labels, patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'), whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'), flierprops=dict(marker='o', markerfacecolor='red', markersize=6, linestyle='none'))

ax.set_xlabel('Desviacion estandar de minutos por mes consumidos') # Corrected label
ax.set_title('Desviacion estandar de Minutos Mensuales Consumidos por Plan') # Corrected title

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
print(f'Grafico de caja de la Desviacione estandar\n de minutos consumidos por mes del plan surf y ultimate') # Corrected print statement
print('\n')

plt.show()
# Out:
# Grafico de caja de la Desviacione estandar
#  de minutos consumidos por mes del plan surf y ultimate

# %% [markdown]
# La desviación estándar mide la dispersión de un conjunto de datos alrededor de su media. En este caso:
#
# desviacion_estandar_surf (127.18): Este valor para el plan Surf indica que el promedio mensual de minutos consumidos por los usuarios de Surf tiende a variar en aproximadamente 127.18 minutos con respecto al uso mensual promedio. Una desviación estándar menor sugeriría un patrón de uso más consistente para el promedio mensual de minutos.
#
# desviacion_estandar_ultimate (129.46): Este valor para el plan Ultimate indica que el promedio mensual de minutos consumidos por los usuarios de Ultimate tiende a variar en aproximadamente 129.46 minutos con respecto al uso mensual promedio. En comparación con el plan Surf, el plan Ultimate muestra una desviación estándar ligeramente mayor, lo que sugiere una fluctuación ligeramente mayor en el promedio mensual de minutos consumidos a lo largo del tiempo, aunque el uso promedio general pueda ser similar o incluso solo un poco mayor.
#
# como se puede observar para ambos planes la media se encuentra entre los 200 y 250 minutos se puede observar que la desviacion estandar del plan surf es menor, respecto a sus valores maximos y minimos y la desviacion estandar del plan ultimate presenta una mayor desviacion estandart respecto a la media mostrando valores maximos y minimos mas amplios lo que se puede deber a ina amplitud en los valores de su plan.

# %% [markdown]
# [Elabora las conclusiones sobre el comportamiento de los usuarios con respecto a las llamadas. ¿Su comportamiento varía en función del plan?]

# %% [markdown]
# En resumen, ambos planes muestran un comportamiento de consumo que tiende a aumentar hacia el final del año, y ambos presentan una variabilidad considerable en el uso de minutos. Sin embargo, para determinar cuál es más rentable, necesitaríamos un análisis más profundo que compare los ingresos generados por cada plan en relación con el costo de los servicios brindados.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor       </b> <a class="tocSkip"></a>
#
# Bien hecho con los análisis de distribución y del cálculo de media y varianza. Estos nos indican que ambos planes son similares en consumo de llamadas.
#
# </div>

# %% [markdown]
# ### Mensajes

# %%
## Calculate the average msg per month for each plan
avg_msg_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].mean().reset_index()

# Now, we can filter this result to get the average for each plan separately
msgprom_msgxmes_plansurf = avg_msg_per_month_per_plan[avg_msg_per_month_per_plan['plan_name'] == 'surf']
msgprom_msgxmes_planult = avg_msg_per_month_per_plan[avg_msg_per_month_per_plan['plan_name'] == 'ultimate']
print('promedio de mensajes consumidos por mes del plan surf y ultimate')
print('\n')
print('promedio de mensajes consumidos del plan surf')
print('\n')
print(msgprom_msgxmes_plansurf)
print('\n')
print('promedio de mensajes consumidos del plan ultimate')
print('\n')
print(msgprom_msgxmes_planult)
# Out:
# promedio de mensajes consumidos por mes del plan surf y ultimate
#
#
# promedio de mensajes consumidos del plan surf
#
#
#     month plan_name  messages_cons
# 0       0      surf       0.000000
# 2       1      surf      10.500000
# 4       2      surf      12.000000
# 6       3      surf      15.260870
# 8       4      surf      17.400000
# 10      5      surf      24.012987
# 12      6      surf      25.298969
# 14      7      surf      27.033058
# 16      8      surf      28.777778
# 18      9      surf      30.762887
# 20     10      surf      33.839662
# 22     11      surf      32.385159
# 24     12      surf      38.600629
#
#
# promedio de mensajes consumidos del plan ultimate
#
#
#     month plan_name  messages_cons
# 1       0  ultimate       0.000000
# 3       1  ultimate      15.500000
# 5       2  ultimate      21.571429
# 7       3  ultimate      20.250000
# 9       4  ultimate      22.047619
# 11      5  ultimate      32.103448
# 13      6  ultimate      29.340426
# ...

# %%
#traza un grafico de barras para visualizarla
import matplotlib.pyplot as plt

# Plot for msg Surf plan
ax = msgprom_msgxmes_plansurf.plot(x='month',
                               y='messages_cons', # Corrected y-axis: use the actual column name
                               kind='bar',
                               title='Average Messages Per Month for Surf and Ultimate Plans',
                               xlabel='Month',
                               ylabel='Average msg',
                               color='skyblue',
                               figsize=(7, 4)
                               )

# Plot for msg Ultimate plan on the same axes
msgprom_msgxmes_planult.plot(x='month',
                              y='messages_cons', # Corrected y-axis: use the actual column name
                              kind='bar',
                              ax=ax, # Plot on the same axes as the first plot
                              alpha=0.7, # Transparency for overlay
                              color='grey'
                              )

plt.legend(['Surf', 'Ultimate'])
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
print(f'Grafico de mensajes promedio por mes del plan surf y ultimate')
print('\n')
plt.show()
# Out:
# Grafico de mensajes promedio por mes del plan surf y ultimate

# %% [markdown]
# El promedio de mensajes para ambos planes tiene una tendencia en ascenso durante toodo el año siendo mas alto su consumo durante los meses para finalizar el año, y el mes con mas mensajes se encuentra en el mes de  Diciembre posiblemente asociado a un mes festivo asociado compartir con los seres queridos. Siendo el plan ultimate mas consumido.

# %%
import pandas as pd

# Comprara el número de mensajes que tienden a enviar cada mes los usuarios de cada plan

# Agrupar numero de mensajes y calcular la suma, luego resetear el index para obtener un DataFrame
messages_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].sum().reset_index()

# Ahora puedes filtrar el DataFrame resultante por plan_name
msgxmes_plansurf = messages_per_month_per_plan[messages_per_month_per_plan['plan_name'] == 'surf']
msgxmes_planult = messages_per_month_per_plan[messages_per_month_per_plan['plan_name'] == 'ultimate']

print('numero de mensajes consumidos por mes de ambos planes,'
'\nplan surf y ultimate')
print('\n')
print('numero de mensajes consumidos por mes del plan surf')
print('\n')
print(msgxmes_plansurf)
print('numero de mensajes consumidos por mes del plan ultimate')
print('\n')
print(msgxmes_planult)
# Out:
# numero de mensajes consumidos por mes de ambos planes,
# plan surf y ultimate
#
#
# numero de mensajes consumidos por mes del plan surf
#
#
#     month plan_name  messages_cons
# 0       0      surf              0
# 2       1      surf             21
# 4       2      surf            108
# 6       3      surf            351
# 8       4      surf            870
# 10      5      surf           1849
# 12      6      surf           2454
# 14      7      surf           3271
# 16      8      surf           4662
# 18      9      surf           5968
# 20     10      surf           8020
# 22     11      surf           9165
# 24     12      surf          12275
# numero de mensajes consumidos por mes del plan ultimate
#
#
#     month plan_name  messages_cons
# 1       0  ultimate              0
# 3       1  ultimate             62
# 5       2  ultimate            151
# 7       3  ultimate            243
# 9       4  ultimate            463
# 11      5  ultimate            931
# ...

# %% [markdown]
# Podemos observar respecto a los mensajes mensuales del plan surf que presenta un primer cuartil cerca de de los 300 mensajes una mediana cerca de los 2400 mensajes y un tercer cuartil cerca de los 5800 mensajes que corresponde a meses cercanos al fin de año y un valor maximo de 11884 mensajes que corresponde a el mes de diciembre.

# %%
#Histograma
import matplotlib.pyplot as plt

# Filter dfcompilated for 'surf' and 'ultimate' plans
surf_min = dfcompilated[dfcompilated['plan_name'] == 'surf']['messages_cons']
ultimate_min = dfcompilated[dfcompilated['plan_name'] == 'ultimate']['messages_cons']

# Create a figure and axes
fig, ax = plt.subplots(figsize=(7, 4))

# Plot histograms for each plan
surf_min.hist(ax=ax, bins=12, alpha=0.7, color='skyblue', label='Surf')
ultimate_min.hist(ax=ax, bins=12, alpha=0.7, color='grey', label='Ultimate')

ax.set_xlabel('Total Monthly Messages Consumed')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Total Monthly Messages Consumed by Plan')
ax.legend()
plt.tight_layout()
print(f'Histogramna del total de Messages consumidos por mes del plan surf y ultimate')
print('\n')
plt.show()
# Out:
# Histogramna del total de Messages consumidos por mes del plan surf y ultimate

# %% [markdown]
# En este histograma podemos observar
#
# En el histograma de los minutos totales consumidospor mes del plan surf y ultimate se observa una mayor densidad para el plan surf y una menor densidad para el plan ultimate, con una media cerca de los 750 min para el plan surf y de 220 minutos para el plan ultimate por lo que es evidente que el plan ultimate no es tan consumido como el plan surf y que su uso es muy por debajo de los beneficios respecto a mensajes que el plan ofrece.
#
# Plan Surf (azul claro): La distribución de mensajes para el plan Surf tiene un sesgo hacia la derecha, muestra un pico en el rango de mensajes más bajos, pero se extiende considerablemente hacia un mayor número de mensajes. Esto sugiere que, si bien muchos usuarios de Surf envían una cantidad moderada de mensajes, un número significativo de ellos supera los límites incluidos en su plan, lo que podría generar cargos adicionales. La distribución parece más dispersa.
#
# Plan Ultimate (gris): Para el plan Ultimate, la distribución también muestra un sesgo hacia la derecha, muestra pico en los mensajes más bajos, pero la frecuencia disminuye más rápidamente a medida que aumenta el número de mensajes. Esto indica que la mayoría de los usuarios de Ultimate no utilizan el gran volumen de mensajes incluidos en su plan (1000 mensajes). La distribución es más concentrada en la parte inferior, sugiriendo que estos usuarios rara vez, o nunca, alcanzan el límite de mensajes de su plan.
#
# Una pre conclusion mediante las observaciones realizadas nos nos permiten decir que l comportamiento de los usuarios difiere entre los planes en cuanto al consumo de mensajes. Los usuarios del plan Surf tienden a utilizar una cantidad de mensajes que, en muchos casos, los lleva a acercarse o superar su límite incluido. En contraste, los usuarios del plan Ultimate, a pesar de tener un límite mucho más generoso, generalmente no lo aprovechan al máximo, enviando una cantidad de mensajes muy inferior a la provista en su plan. Esto podría indicar que el plan Ultimate ofrece más mensajes de los que la mayoría de sus usuarios necesita.

# %%
## Calculate the measures of statistical tendency msg per month for each plan
#calcular la varianza
var_msg_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].var().reset_index()

# Now, we can filter this result to get the average for each plan separately
msgvar_msgxmes_plansurf = var_msg_per_month_per_plan[avg_msg_per_month_per_plan['plan_name'] == 'surf']
msgvar_msgxmes_planult = var_msg_per_month_per_plan[avg_msg_per_month_per_plan['plan_name'] == 'ultimate']

print
print(f'Varianza de mensajes consumidos\n de ambos planes')
print('\n')
print('Varianza de mensajes consumidos\n plan surf')
print('\n')
print(msgvar_msgxmes_plansurf)
print('\n')
print('Varianza de mensajes consumidos\n plan ultimate')
print('\n')
print(msgvar_msgxmes_planult)
print('\n')
# Out:
# Varianza de mensajes consumidos
#  de ambos planes
#
#
# Varianza de mensajes consumidos
#  plan surf
#
#
#     month plan_name  messages_cons
# 0       0      surf       0.000000
# 2       1      surf     220.500000
# 4       2      surf     386.000000
# 6       3      surf     346.565217
# 8       4      surf     501.591837
# 10      5      surf     847.197198
# 12      6      surf     914.920103
# 14      7      surf     923.915565
# 16      8      surf    1029.515528
# 18      9      surf    1003.829496
# 20     10      surf    1275.465708
# 22     11      surf    1065.344034
# 24     12      surf    1458.158612
#
#
# Varianza de mensajes consumidos
#  plan ultimate
#
#
#     month plan_name  messages_cons
# 1       0  ultimate       0.000000
# 3       1  ultimate     313.666667
# 5       2  ultimate     478.285714
# 7       3  ultimate     654.386364
# 9       4  ultimate     544.147619
# 11      5  ultimate    1297.310345
# 13      6  ultimate     857.620722
# ...

# %%
# Ambos boxplot de mensajes por mes del plan surf y plan ultimate

import matplotlib.pyplot as plt
import numpy as np

# Ensure dfcompilated is available and messages_cons column is prepared.
# Assuming dfcompilated is already defined from previous steps and 'messages_cons' is correctly processed.

# Re-define messages_per_month_per_plan, msgxmes_plansurf, and msgxmes_planult
var_messages_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].var().reset_index()

msgxmes_plansurf = var_messages_per_month_per_plan[var_messages_per_month_per_plan['plan_name'] == 'surf']
msgxmes_planult = var_messages_per_month_per_plan[var_messages_per_month_per_plan['plan_name'] == 'ultimate']

# Prepare data for box plots
data_to_plot = [
    msgxmes_plansurf['messages_cons'],
    msgxmes_planult['messages_cons']
]

labels = ['Plan Surf', 'Plan Ultimate']

fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot(data_to_plot, vert=False, labels=labels, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'),
           whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'),
           flierprops=dict(marker='o', markerfacecolor='red', markersize=6,
                           linestyle='none'))

ax.set_xlabel('Mensajes por mes consumidos')
ax.set_title('Distribución de Mensajes Mensuales Consumidos por Plan')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
print(f'Grafico de caja de la varianza de mensajes\n consumidos por mes del plan surf y ultimate')
print('\n')

plt.show()
# Out:
# Grafico de caja de la varianza de mensajes
#  consumidos por mes del plan surf y ultimate

# %% [markdown]
# Podemos observar respecto a los mensajes mensuales del plan ultimate que presenta un primer cuartil cerca de los 600 mensajes que corresponde a los primeros meses y un segundo cuartil o una mediana de 900  mensajes que corresponde a mediados de año, un tercer cualtil cerca de 1200 mensajes que corresponde a algunos meses anteriores al fin de año con un valor maximo de 1500 mensajes que corresponden al mes de diciembre quizas atribuido a que es un mes festivo y familiar. Muestra una tendencia similar a la del plan surf sin embargo muestra un primer cuartil cercano a los 400 mensajes, lo cual significa que respecto a los mensajes una mediana cerca de los 900 mensajes y un tercer cuartil cerca de los 1050 mensjaes con valores maximos arriba de los 1400 lo cual indica que su consumo es muy similar al plan ultimate, de lo que podemos destacar que el plan ultimate se encuentra muy sobredesestimado respecto a su uso.

# %% [markdown]
# Varianza: Nos dice qué tan lejos están los números de la media. Una varianza alta significa que los valores individuales están lejos de la media y entre sí, indicando una mayor dispersión. Una varianza baja significa que los valores tienden a agruparse cerca de la media, indicando menor dispersión.
#
# Varianza de Mensajes Consumidos por Mes (Surf vs. Ultimate):
#
# Plan Surf (msgvar_msgxmes_plansurf): La varianza en el consumo de mensajes por mes para el plan Surf muestra un aumento constante a lo largo del año, con valores que van desde 220 hasta 1474.21 en diciembre. Esto indica que la variabilidad en la cantidad de mensajes enviados por los usuarios del plan Surf tiende a ser mayor a medida que avanza el año. Hay una dispersión considerable en el uso de mensajes entre los usuarios de este plan, especialmente en los meses de mayor actividad.
# Plan Ultimate (msgvar_msgxmes_planult): Similar al plan Surf, la varianza para el plan Ultimate también aumenta a lo largo del año, llegando a 1549.31 en diciembre. Esto sugiere que también hay una creciente variabilidad en el uso de mensajes entre los usuarios de Ultimate a medida que avanza el año.

# %%
### Calculate the measures of statistical tendency msg per month for each plan
#calcular la desviacion estandart
des_est_msg_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].std().reset_index()

#Ahora filtraremos por separado cada plan
des_est_msgxmes_plansurf = des_est_msg_per_month_per_plan[avg_msg_per_month_per_plan['plan_name'] == 'surf']
des_est_msgxmes_planult = des_est_msg_per_month_per_plan[avg_msg_per_month_per_plan['plan_name'] == 'ultimate']
print(f'Desviacion estandar de mensajes consumidos\n de ambos planes')
print('\n')
print('Desviacion estandar de mensajes consumidos\n plan surf')
print('\n')
print(des_est_msgxmes_plansurf)
print('\n')
print('Desviacion estandar de mensajes consumidos\n plan ultimate')
print('\n')
print(des_est_msgxmes_planult)
# Out:
# Desviacion estandar de mensajes consumidos
#  de ambos planes
#
#
# Desviacion estandar de mensajes consumidos
#  plan surf
#
#
#     month plan_name  messages_cons
# 0       0      surf       0.000000
# 2       1      surf      14.849242
# 4       2      surf      19.646883
# 6       3      surf      18.616262
# 8       4      surf      22.396246
# 10      5      surf      29.106652
# 12      6      surf      30.247646
# 14      7      surf      30.395979
# 16      8      surf      32.086064
# 18      9      surf      31.683268
# 20     10      surf      35.713663
# 22     11      surf      32.639608
# 24     12      surf      38.185843
#
#
# Desviacion estandar de mensajes consumidos
#  plan ultimate
#
#
#     month plan_name  messages_cons
# 1       0  ultimate       0.000000
# 3       1  ultimate      17.710637
# 5       2  ultimate      21.869744
# 7       3  ultimate      25.580977
# 9       4  ultimate      23.326972
# 11      5  ultimate      36.018195
# ...

# %%
# Ambos boxplot de mensajes por mes del plan surf y plan ultimate

import matplotlib.pyplot as plt
import numpy as np

# Ensure dfcompilated is available and messages_cons column is prepared.
# Assuming dfcompilated is already defined from previous steps and 'messages_cons' is correctly processed.

# Re-define messages_per_month_per_plan, msgxmes_plansurf, and msgxmes_planult

std_msg_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].std().reset_index()

# Now, we can filter this result to get the average for each plan separately
msgstd_msgxmes_plansurf = std_msg_per_month_per_plan[std_msg_per_month_per_plan['plan_name'] == 'surf']
msgstd_msgxmes_planult = std_msg_per_month_per_plan[std_msg_per_month_per_plan['plan_name'] == 'ultimate']

#var_messages_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['messages_cons'].var().reset_index()

#msgxmes_plansurf = var_messages_per_month_per_plan[var_messages_per_month_per_plan['plan_name'] == 'surf']
#msgxmes_planult = var_messages_per_month_per_plan[var_messages_per_month_per_plan['plan_name'] == 'ultimate']

# Prepare data for box plots
data_to_plot = [
    msgstd_msgxmes_plansurf['messages_cons'],
    msgstd_msgxmes_planult['messages_cons']
]

labels = ['Plan Surf', 'Plan Ultimate']

fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot(data_to_plot, vert=False, labels=labels, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'),
           whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'),
           flierprops=dict(marker='o', markerfacecolor='red', markersize=6,
                           linestyle='none'))

ax.set_xlabel('Mensajes por mes consumidos')
ax.set_title('Distribución de std  Mensajes Mensuales Consumidos por Plan')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
print(f'Grafico de caja de la Desviacion estandar de mensajes\n consumidos por mes del plan surf y ultimate')
print('\n')

plt.show()
# Out:
# Grafico de caja de la Desviacion estandar de mensajes
#  consumidos por mes del plan surf y ultimate

# %% [markdown]
# Varianza: Nos dice qué tan lejos están los números de la media. Una varianza alta significa que los valores individuales están lejos de la media y entre sí, indicando una mayor dispersión. Una varianza baja significa que los valores tienden a agruparse cerca de la media, indicando menor dispersión.
#
# Varianza de Mensajes Consumidos por Mes (Surf vs. Ultimate):
#
# Plan Surf (msgvar_msgxmes_plansurf): La varianza en el consumo de mensajes por mes para el plan Surf muestra un aumento constante a lo largo del año, con valores que van desde 220 hasta 1474.21 en diciembre. Esto indica que la variabilidad en la cantidad de mensajes enviados por los usuarios del plan Surf tiende a ser mayor a medida que avanza el año. Hay una dispersión considerable en el uso de mensajes entre los usuarios de este plan, especialmente en los meses de mayor actividad.
# Plan Ultimate (msgvar_msgxmes_planult): Similar al plan Surf, la varianza para el plan Ultimate también aumenta a lo largo del año, llegando a 1549.31 en diciembre. Esto sugiere que también hay una creciente variabilidad en el uso de mensajes entre los usuarios de Ultimate a medida que avanza el año.

# %% [markdown]
# Desviación Estándar: Es la raíz cuadrada de la varianza y se expresa en las mismas unidades que los datos originales, lo que la hace más interpretable. Una desviación estándar alta indica que los puntos de datos están muy dispersos de la media, mientras que una baja indica que están más cerca de la media.
#
# Desviación Estándar de Mensajes Consumidos por Mes (Surf vs. Ultimate):
#
# Plan Surf (des_est_msgxmes_plansurf): La desviación estándar para el plan Surf oscila entre 14 y 38.40 mensajes. Esto significa que, en promedio, el consumo mensual de mensajes de los usuarios de Surf se desvía de la media mensual en estas cantidades.
# Plan Ultimate (des_est_msgxmes_planult): La desviación estándar para el plan Ultimate varía entre 17 y 39.36 mensajes. Esto indica que la dispersión en el consumo de mensajes para los usuarios de Ultimate es similar o ligeramente mayor que la del plan Surf en algunos meses.

# %% [markdown]
# [Elabora las conclusiones sobre el comportamiento de los usuarios con respecto a los mensajes. ¿Su comportamiento varía en función del plan?]

# %% [markdown]
# Conclusión sobre el comportamiento de los usuarios respecto a los mensajes:
#
# Observaciones generales (ambos planes): El consumo de mensajes muestra una distribución con una mediana relativamente baja y una cola larga, indicando que la mayoría envía un número moderado, pero hay usuarios muy activos. Plan Surf: Los usuarios tienden a enviar una cantidad considerable de mensajes, con una tendencia a un uso más activo, llegando incluso a superar los límites incluidos en su tarifa. Plan Ultimate: A pesar de tener un límite de 1000 mensajes, muchos usuarios no lo aprovechan al máximo, mostrando una distribución de consumo más concentrada en la parte inferior. La variabilidad puede ser menor o similar a la del plan Surf, pero menos usuarios alcanzan niveles de consumo muy altos

# %% [markdown]
# ¿Su comportamiento varía en función del plan?
#
# Sí, el comportamiento varía. El plan Surf, con un límite más bajo (50 mensajes), puede incentivar un uso más cercano o por encima de su límite. En cambio, los usuarios del plan Ultimate, con su generoso límite de 1000 mensajes, muestran un patrón de uso más relajado, con la mayoría consumiendo muy por debajo del límite. En resumen, los usuarios de Surf tienden a tener un consumo más 'apretado' en torno a su límite (o excediéndolo), mientras que los de Ultimate tienen una distribución más amplia en la parte inferior, ya que la mayoría no necesita tantos mensajes como los que ofrece su plan.
# En resumen, mientras que los usuarios de Surf pueden mostrar una distribución más 'apretada' en torno a su límite (o excediéndolo), los usuarios de Ultimate pueden tener una distribución más amplia en la parte inferior, ya que la mayoría no llega ni de lejos a su asignación.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
# Excelente, muy bien con la comparación del consumo de mensajes entre los planes. Vemos que se diferencian más que las llamadas.
#
#
#
# </div>

# %% [markdown]
# ### Internet

# %%
# Calculate the average mb per month for each plan
avg_mb_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['mb_cons'].mean().reset_index()

# Now, we can filter this result to get the average for each plan separately
mbprom_xmes_plansurf = avg_mb_per_month_per_plan[avg_mb_per_month_per_plan['plan_name'] == 'surf']
mbprom_xmes_planult = avg_mb_per_month_per_plan[avg_mb_per_month_per_plan['plan_name'] == 'ultimate']
print(f'promedio de MB consumidos por mes del plan surf y ultimate')
print('\n')
print('promedio de MB consumidos del plan surf')
print('\n')
print(mbprom_xmes_plansurf)
print('\n')
print('promedio de MB consumidos del plan ultimate')
print('\n')
print(mbprom_xmes_planult)
# Out:
# promedio de MB consumidos por mes del plan surf y ultimate
#
#
# promedio de MB consumidos del plan surf
#
#
#     month plan_name       mb_cons
# 0       0      surf      0.000000
# 2       1      surf   4868.000000
# 4       2      surf  12163.666667
# 6       3      surf  13330.652174
# 8       4      surf  11969.920000
# 10      5      surf  13920.246753
# 12      6      surf  15282.948454
# 14      7      surf  16764.165289
# 16      8      surf  16775.771605
# 18      9      surf  16571.819588
# 20     10      surf  17290.848101
# 22     11      surf  16319.692580
# 24     12      surf  18111.034591
#
#
# promedio de MB consumidos del plan ultimate
#
#
#     month plan_name       mb_cons
# 1       0  ultimate      0.000000
# 3       1  ultimate   6911.250000
# 5       2  ultimate  17110.285714
# 7       3  ultimate  18301.583333
# 9       4  ultimate  16103.333333
# 11      5  ultimate  16605.517241
# 13      6  ultimate  15320.361702
# 15      7  ultimate  16325.050847
# ...

# %%
#traza un grafico de barras para visualizarla
import matplotlib.pyplot as plt

# Plot for Surf plan
ax = mbprom_xmes_plansurf.plot(x='month',
                               y='mb_cons', # Corrected y-axis: use the actual column name
                               kind='bar',
                               title='Average MB Per Month for Surf and Ultimate Plans',
                               xlabel='Month',
                               ylabel='Average MB',
                               color='skyblue',
                               figsize=(7, 4)
                               )

# Plot for Ultimate plan on the same axes
mbprom_xmes_planult.plot(x='month',
                              y='mb_cons', # Corrected y-axis: use the actual column name
                              kind='bar',
                              ax=ax, # Plot on the same axes as the first plot
                              alpha=0.7, # Transparency for overlay
                              color='grey'
                              )

plt.legend(['Surf', 'Ultimate'])
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
print(f'Grafico de MB promedio en MB por mes del plan surf y ultimate')
plt.show()
# Out:
# Grafico de MB promedio en MB por mes del plan surf y ultimate

# %% [markdown]
# Grafico de MB promedio en MB por mes del plan surf y ultimate nos permite observar una tendencia General: Ambos planes muestran una clara tendencia al alza en el consumo promedio de MB a lo largo del año. El consumo es menor a principios de año (enero-febrero) y aumenta significativamente hacia los últimos meses (octubre-diciembre). Esto podría deberse a factores estacionales, como vacaciones o mayor actividad hacia el final del año.
#
# Diferencias por Plan:
# El plan Ultimate consistentemente registra un mayor consumo promedio de MB por mes en comparación con el plan Surf. Incluso en los meses iniciales, el consumo promedio del plan Ultimate es superior.
#
# Plan Ultimate consistentemente registra un mayor consumo promedio de MB por mes en comparación con el Plan Surf.
# Los usuarios del Plan Surf (límite de 15,000 MB) frecuentemente exceden este límite, especialmente de agosto a diciembre, incurriendo en cargos adicionales.
# Los usuarios del Plan Ultimate (límite de 30,000 MB) se mantienen holgadamente dentro de su límite, a pesar de tener un mayor consumo promedio que los de Surf.
#
# El plan Surf tiene un límite de 15,000 MB incluidos, y observamos que en varios meses (especialmente a partir de agosto/septiembre y hasta diciembre), el consumo promedio de sus usuarios está por encima de este límite. Esto implica que muchos usuarios de Surf están pagando por megabytes adicionales.
# El plan Ultimate tiene un límite mucho más generoso de 30,000 MB incluidos. Aunque sus usuarios consumen más MB en promedio que los de Surf, su consumo promedio se mantiene siempre por debajo de su límite incluido. Esto sugiere que la mayoría de los usuarios de Ultimate no alcanzan su tope de datos y, por lo tanto, no incurren en costos adicionales por exceso de datos.
#
# Conclusión:
#
# El comportamiento de los usuarios en cuanto al consumo de internet varía significativamente entre los planes. Los usuarios del plan Surf tienden a exceder sus límites de datos incluidos, especialmente a segunda mitad del año y en los meses de mayor actividad, lo que probablemente genera ingresos adicionales para Megaline por MB extra. Por otro lado, los usuarios del plan Ultimate, a pesar de consumir más MB en general, rara vez (o nunca, en promedio) alcanzan su límite, lo que significa que la empresa no está monetizando un uso excesivo de datos de estos clientes. Esto podría indicar que el plan Ultimate ofrece una asignación de datos excesivamente alta para el consumo promedio de sus usuarios, mientras que el plan Surf podría estar subestimando las necesidades de datos de sus clientes en los meses de mayor uso.

# %%
# Compara la cantidad de tráfico total de Internet consumido por usuarios por plan
sumtot_mb_per_per_plan = dfcompilated.groupby(['month', 'plan_name'])['mb_cons'].sum().reset_index()

sumtot_mb_xmes_plansurf = sumtot_mb_per_per_plan[sumtot_mb_per_per_plan['plan_name'] == 'surf']
sumtot_mb_xmes_planult = sumtot_mb_per_per_plan[sumtot_mb_per_per_plan['plan_name'] == 'ultimate']

print(f'Cantidad total de MB consumidos por mes del plan surf y ultimate')
print('\n')
print('Cantidad total de MB consumidos del plan surf')
print('\n')
print(sumtot_mb_xmes_plansurf)
print('\n')
print('Cantidad total de MB consumidos del plan ultimate')
print('\n')
print(sumtot_mb_xmes_planult)
# Out:
# Cantidad total de MB consumidos por mes del plan surf y ultimate
#
#
# Cantidad total de MB consumidos del plan surf
#
#
#     month plan_name  mb_cons
# 0       0      surf        0
# 2       1      surf     9736
# 4       2      surf   109473
# 6       3      surf   306605
# 8       4      surf   598496
# 10      5      surf  1071859
# 12      6      surf  1482446
# 14      7      surf  2028464
# 16      8      surf  2717675
# 18      9      surf  3214933
# 20     10      surf  4097931
# 22     11      surf  4618473
# 24     12      surf  5759309
#
#
# Cantidad total de MB consumidos del plan ultimate
#
#
#     month plan_name  mb_cons
# 1       0  ultimate        0
# 3       1  ultimate    27645
# 5       2  ultimate   119772
# 7       3  ultimate   219619
# 9       4  ultimate   338170
# 11      5  ultimate   481560
# 13      6  ultimate   720057
# 15      7  ultimate   963178
# 17      8  ultimate  1263342
# 19      9  ultimate  1457700
# 21     10  ultimate  1864838
# ...

# %%
#Histograma
import matplotlib.pyplot as plt

# Filter dfcompilated for 'surf' and 'ultimate' plans
surf_mb = dfcompilated[dfcompilated['plan_name'] == 'surf']['mb_cons']
ultimate_mb = dfcompilated[dfcompilated['plan_name'] == 'ultimate']['mb_cons']

# Create a figure and axes
fig, ax = plt.subplots(figsize=(7, 4))

# Plot histograms for each plan
surf_mb.hist(ax=ax, bins=12, alpha=0.7, color='skyblue', label='Surf')
ultimate_mb.hist(ax=ax, bins=12, alpha=0.7, color='grey', label='Ultimate')

ax.set_xlabel('Total Monthly MB Consumed')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Total Monthly MB Consumed by Plan')
ax.legend()
plt.tight_layout()
print(f'Histogramna del total de MB consumidos por mes del plan surf y ultimate')
print('\n')
plt.show()
# Out:
# Histogramna del total de MB consumidos por mes del plan surf y ultimate

# %% [markdown]
# Tendencia General:
#  En el histograma de los mb totales consumidos por mes del plan surf y ultimate se observa una mayor densidad para el plan surf y una menor densidad para el plan ultimate, con una media cerca de los 15000 mb para el plan surf y de 17500 mb para el plan ultimate por lo que es evidente que el plan ultimate no es tan consumido como el plan surf y que su uso es muy por debajo de los beneficios respecto a mb que el plan ofrece.
#
# Ambos planes muestran un aumento constante en el consumo promedio de MB a lo largo del año, siendo menor al principio (enero-febrero) y aumentando significativamente hacia los últimos meses (octubre-diciembre). Esto podría deberse a factores estacionales como vacaciones o mayor actividad.

# %%
## Calculate the measures of statistical tendency msg per month for each plan
#calcular la varianza
var_mb_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['mb_cons'].var().reset_index()

# Now, we can filter this result to get the average for each plan separately
mbvar_mbxmes_plansurf = var_mb_per_month_per_plan[var_mb_per_month_per_plan['plan_name'] == 'surf']
mbvar_mbxmes_planult = var_mb_per_month_per_plan[var_mb_per_month_per_plan['plan_name'] == 'ultimate']
gbmbvar_mbxmes_plansurf = mbvar_mbxmes_plansurf['mb_cons'] / 1024
gbmbvar_mbxmes_planult = mbvar_mbxmes_planult['mb_cons'] / 1024
print(f'Varianza de mb consumidos\n de ambos planes GB')
print('\n')
print('Varianza de mb consumidos\n por mes del plan surf')
print('\n')
print(gbmbvar_mbxmes_plansurf)
print('\n')
print('Varianza de mb consumidos\n por mes del plan ultimate')
print('\n')
print(gbmbvar_mbxmes_planult)
print('\n')
print(f'Varianza de mb consumidos\n de ambos planes')
print('\n')
print('Varianza de mb consumidos\n plan surf')
print('\n')
print(mbvar_mbxmes_plansurf)
print('\n')
print('Varianza de mb consumidos\n plan ultimate')
print('\n')
print(mbvar_mbxmes_planult)
print('\n')
# Out:
# Varianza de mb consumidos
#  de ambos planes GB
#
#
# Varianza de mb consumidos
#  por mes del plan surf
#
#
# 0         0.000000
# 2     17777.908203
# 4     42543.076660
# 6     66504.031393
# 8     57535.291767
# 10    59914.356244
# 12    47890.909818
# 14    63050.216233
# 16    72741.738297
# 18    50015.317128
# 20    60944.510703
# 22    55721.570431
# 24    70320.521492
# Name: mb_cons, dtype: float64
#
#
# Varianza de mb consumidos
#  por mes del plan ultimate
#
#
# 1          0.000000
# 3      15982.806885
# 5      36677.965402
# 7     136779.283995
# 9      86189.622591
# 11     55368.294895
# 13     70200.124211
# 15     66684.592013
# 17     58927.055184
# 19     48095.603401
# 21     55565.231252
# 23     56138.649363
# 25     60317.937635
# Name: mb_cons, dtype: float64
#
#
# Varianza de mb consumidos
#  de ambos planes
#
#
# Varianza de mb consumidos
#  plan surf
#
#
#     month plan_name       mb_cons
# 0       0      surf  0.000000e+00
# ...

# %%
# Ambos boxplot de mensajes por mes del plan surf y plan ultimate

import matplotlib.pyplot as plt
import numpy as np

# Ensure dfcompilated is available and messages_cons column is prepared.
# Assuming dfcompilated is already defined from previous steps and 'mb_cons' is correctly processed.


var_mb_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['mb_cons'].var().reset_index()

# Now, we can filter this result to get the average for each plan separately
mbvar_mbxmes_plansurf = var_mb_per_month_per_plan[var_mb_per_month_per_plan['plan_name'] == 'surf']
mbvar_mbxmes_planult = var_mb_per_month_per_plan[var_mb_per_month_per_plan['plan_name'] == 'ultimate']
gbmbvar_mbxmes_plansurf = mbvar_mbxmes_plansurf['mb_cons'] / 1024
gbmbvar_mbxmes_planult = mbvar_mbxmes_planult['mb_cons'] / 1024
# Prepare data for box plots
data_to_plot = [
    gbmbvar_mbxmes_plansurf,
    gbmbvar_mbxmes_planult
]

labels = ['Plan Surf', 'Plan Ultimate']

fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot(data_to_plot, vert=False, labels=labels, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'),
           whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'),
           flierprops=dict(marker='o', markerfacecolor='red', markersize=6,
                           linestyle='none'))

ax.set_xlabel('mb por mes consumidos')
ax.set_title('Distribución de GB Mensuales Consumidos por Plan')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
print(f'Grafico de caja del total de la varianza GB\n consumidos por mes del plan surf y ultimate')
print('\n')

plt.show()
# Out:
# Grafico de caja del total de la varianza GB
#  consumidos por mes del plan surf y ultimate

# %% [markdown]
# Varianza (en GB):
# Plan Surf:
#
# La varianza en GB varía desde 0 en el mes 0 hasta aproximadamente 73 GB en el mes de diciembre. Esto indica una considerable fluctuación en la dispersión del consumo de MB por mes para los usuarios de Surf.
# Plan Ultimate: La varianza en GB también muestra fluctuaciones, alcanzando un pico de aproximadamente 133 GB en el mes 3, y alrededor de 57 GB en diciembre. En ciertos meses, la varianza del Plan Ultimate puede ser significativamente mayor que la del Plan Surf, sugiriendo una mayor diversidad en el comportamiento de los usuarios en términos de consumo de datos.

# %%
## Calculate the measures of statistical tendency msg per month for each plan
#calcular la desviaciion estandart
desv_est_totmb_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['mb_cons'].std().reset_index()

# Now, we can filter this result to get the average for each plan separately
mbstd_mbxmes_plansurf = desv_est_totmb_per_month_per_plan[desv_est_totmb_per_month_per_plan['plan_name'] == 'surf']
mbstd_mbxmes_planult = desv_est_totmb_per_month_per_plan[desv_est_totmb_per_month_per_plan['plan_name'] == 'ultimate']
gbstd_mbxmes_plansurf = mbstd_mbxmes_plansurf['mb_cons'] / 1024
gbstd_mbxmes_planult = mbstd_mbxmes_planult['mb_cons'] / 1024
print(f'Desviacion estandar de GB consumidos\n de ambos planes en GB')
print('\n')
print('Desviacion estandar de GB consumidos por mes del plan surf')
print(gbstd_mbxmes_plansurf)
print('\n')
print('Desviacion estandar de GB consumidos por mes del plan ultimate')
print('\n')
print(gbstd_mbxmes_planult)
print('\n')

print(f'Desviación estandar de mb consumidos\n de ambos planes')
print('\n')
print('Desviacion estandar de mb consumidos\n por mes del plan surf')
print('\n')
print(mbstd_mbxmes_plansurf)
print('\n')
print('Desviaciónestandar de mb consumidos\n por mes del plan ultimate')
print('\n')
print(mbstd_mbxmes_planult)
print('\n')
# Out:
# Desviacion estandar de GB consumidos
#  de ambos planes en GB
#
#
# Desviacion estandar de GB consumidos por mes del plan surf
# 0     0.000000
# 2     4.166682
# 4     6.445617
# 6     8.058867
# 8     7.495786
# 10    7.649190
# 12    6.838747
# 14    7.846813
# 16    8.428336
# 18    6.988783
# 20    7.714669
# 22    7.376693
# 24    8.286880
# Name: mb_cons, dtype: float64
#
#
# Desviacion estandar de GB consumidos por mes del plan ultimate
#
#
# 1      0.000000
# 3      3.950723
# 5      5.984841
# 7     11.557401
# 9      9.174397
# 11     7.353271
# 13     8.279783
# 15     8.069800
# 17     7.585905
# 19     6.853347
# 21     7.366337
# 23     7.404249
# 25     7.674910
# Name: mb_cons, dtype: float64
#
#
# Desviación estandar de mb consumidos
#  de ambos planes
#
#
# Desviacion estandar de mb consumidos
#  por mes del plan surf
#
#
#     month plan_name      mb_cons
# 0       0      surf     0.000000
# 2       1      surf  4266.682318
# 4       2      surf  6600.311394
# ...

# %%
# Ambos boxplot de GB por mes del plan surf y plan ultimate

import matplotlib.pyplot as plt
import numpy as np

desv_est_totmb_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['mb_cons'].std().reset_index()

# Now, we can filter this result to get the average for each plan separately
mbstd_mbxmes_plansurf = desv_est_totmb_per_month_per_plan[desv_est_totmb_per_month_per_plan['plan_name'] == 'surf']
mbstd_mbxmes_planult = desv_est_totmb_per_month_per_plan[desv_est_totmb_per_month_per_plan['plan_name'] == 'ultimate']
gbstd_mbxmes_plansurf = mbstd_mbxmes_plansurf['mb_cons'] / 1024
gbstd_mbxmes_planult = mbstd_mbxmes_planult['mb_cons'] / 1024
# Prepare data for box plots
data_to_plot = [
    gbstd_mbxmes_plansurf,
    gbstd_mbxmes_planult
]

labels = ['Plan Surf', 'Plan Ultimate']

fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot(data_to_plot, vert=False, labels=labels, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'),
           whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'),
           flierprops=dict(marker='o', markerfacecolor='red', markersize=6,
                           linestyle='none'))

ax.set_xlabel('GB por mes consumidos')
ax.set_title('Distribución de GB mensuales Consumidos por Plan')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
print(f'Grafico de caja de la desviacion estandar del total de GB\n consumidos por mes del plan surf y ultimate')
print('\n')

plt.show()
# Out:
# Grafico de caja de la desviacion estandar del total de GB
#  consumidos por mes del plan surf y ultimate

# %% [markdown]
# **Desviación Estándar (en GB):**
#     *   **Plan Surf:** La desviación estándar en GB oscila entre 4 y aproximadamente 8.47 GB (mes 8). Esto significa que, en promedio, el consumo mensual de MB de los usuarios de Surf se desvía de la media mensual en estas cantidades.
#     *   **Plan Ultimate:** La desviación estándar en GB varía entre 3 y aproximadamente 11.58 GB (mes 3). Similar a la varianza, en algunos meses la desviación estándar del Plan Ultimate es más alta, indicando una mayor dispersión en el uso de datos en comparación con el Plan Surf en esos períodos.

# %% [markdown]
# [Elabora las conclusiones sobre cómo los usuarios tienden a consumir el tráfico de Internet. ¿Su comportamiento varía en función del plan?]

# %% [markdown]
# **Conclusión sobre el comportamiento de los usuarios (MB):**
# El comportamiento de los usuarios varía significativamente. El Plan Surf genera ingresos adicionales por exceso de datos, mientras que la generosa asignación de datos del Plan Ultimate podría estar infrautilizada por los usuarios promedio, lo que representa una oportunidad de monetización perdida.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto. El consumo de internet entre planes se ve muy similar.
#
#
#
# </div>

# %% [markdown]
# ## Ingreso

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
#
# Para revisar esta parte de los ingresos y test de hipótesis, se requiere corregir el cálculo de los ingresos de la primera mitad del notebook.
#
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Re: Me parece que ya lo he corregido procedo a revisar esta parte .</b> <a class='tocSkip'></a>
# </div>

# %% [markdown]
# [Del mismo modo que has estudiado el comportamiento de los usuarios, describe estadísticamente los ingresos de los planes.]

# %%
# Grafico de barras para el promedio
# Calculate the average minutes per month for each plan
avg_rev_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['monthly_revenue'].mean().reset_index()

# Now, we can filter this result to get the average revenue for each plan separately
revprom_llamxmes_plansurf = avg_rev_per_month_per_plan[avg_rev_per_month_per_plan['plan_name'] == 'surf']
revprom_llamxmes_planult = avg_rev_per_month_per_plan[avg_rev_per_month_per_plan['plan_name'] == 'ultimate']
print(f'Promedio de ingresos consumidos por mes de ambso planes')
print('\n')
print(f'Promedio de ingresos consumidos por mes del plan surf')
print('\n')
print(revprom_llamxmes_plansurf)
print('\n')
print(f'Promedio de ingresos consumidos por mes del plan ultimate')
print('\n')
print(revprom_llamxmes_planult)
# Out:
# Promedio de ingresos consumidos por mes de ambso planes
#
#
# Promedio de ingresos consumidos por mes del plan surf
#
#
#     month plan_name  monthly_revenue
# 0       0      surf        20.000000
# 2       1      surf        20.000000
# 4       2      surf        34.396667
# 6       3      surf        45.941304
# 8       4      surf        40.710600
# 10      5      surf        47.498312
# 12      6      surf        49.276289
# 14      7      surf        62.508760
# 16      8      surf        63.869444
# 18      9      surf        58.116856
# 20     10      surf        65.210253
# 22     11      surf        57.862933
# 24     12      surf        70.399811
#
#
# Promedio de ingresos consumidos por mes del plan ultimate
#
#
#     month plan_name  monthly_revenue
# 1       0  ultimate        70.000000
# 3       1  ultimate        70.000000
# 5       2  ultimate        70.000000
# 7       3  ultimate        74.666667
# 9       4  ultimate        73.000000
# ...

# %%
#traza un grafico de barras para visualizarla
import matplotlib.pyplot as plt

# Plot for msg Surf plan
ax = revprom_llamxmes_plansurf.plot(x='month',
                               y='monthly_revenue', # Corrected y-axis: use the actual column name
                               kind='bar',
                               title='Promedio de ingresos por mes del plan Surf y Ultimate',
                               xlabel='Month',
                               ylabel='Average Revenue',
                               color='skyblue',
                               figsize=(7, 4)
                               )

# Plot for msg Ultimate plan on the same axes
revprom_llamxmes_planult.plot(x='month',
                              y='monthly_revenue', # Corrected y-axis: use the actual column name
                              kind='bar',
                              ax=ax, # Plot on the same axes as the first plot
                              alpha=0.7, # Transparency for overlay
                              color='grey'
                              )

plt.legend(['Surf', 'Ultimate'])
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
print(f'Grafico de ingresos promedio por mes del plan surf y ultimate')
print('\n')
plt.show()
# Out:
# Grafico de ingresos promedio por mes del plan surf y ultimate

# %% [markdown]
# Observación del promedio y conclusion
#
# Al analizar el ingreso mensual promedio de los planes «Surf» y «Ultimate». El gráfico de barras y los datos muestran una clara diferencia:
#
# Plan Surf (revprom_llamxmes_plansurf): El ingreso mensual promedio del plan Surf comienza bajo ( 20.00 dolares en el mes de enero) y muestra un aumento constante a lo largo del año, alcanzando su punto máximo  (70 dolares en el mes de diciembre). Esta tendencia al alza sugiere que, a medida que avanza el año, los usuarios del plan Surf tienden a incurrir en más cargos, probablemente debido a que superan sus límites de gasto.
#
# Plan Ultimate (revprom_llamxmes_planult): El ingreso mensual promedio del plan Ultimate se mantiene consistentemente alto (entre 70.00 y 73.29 dolares) durante todos los meses. Esta estabilidad es esperable, ya que el plan Ultimate tiene una cuota mensual fija más alta y límites más generosos, lo que significa que es menos probable que los usuarios incurran en cargos adicionales.
#
# Observación general: El plan Ultimate genera consistentemente un ingreso mensual promedio más alto y estable en comparación con el plan Surf. Mientras que los ingresos del plan Surf aumentan a lo largo del año, lo que sugiere que los usuarios superan sus límites con frecuencia, los ingresos del plan Ultimate se mantienen altos desde el principio, lo que indica que su cuota base proporciona un flujo de ingresos normalmente mas fijo y predecible para Megaline.

# %%
# Hsitograma

import matplotlib.pyplot as plt

# Filter dfcompilated for 'surf' and 'ultimate' plans
surf_revenue = dfcompilated[dfcompilated['plan_name'] == 'surf']['monthly_revenue']
ultimate_revenue = dfcompilated[dfcompilated['plan_name'] == 'ultimate']['monthly_revenue']

# Create a figure and axes
fig, ax = plt.subplots(figsize=(7, 4))

# Plot histograms for each plan
surf_revenue.hist(ax=ax, bins=12, alpha=0.7, color='skyblue', label='Surf')
ultimate_revenue.hist(ax=ax, bins=2, alpha=0.7, color='grey', label='Ultimate')

ax.set_xlabel('Total Monthly Revenue Consumed')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Total Monthly Revenue Consumed by Plan')
ax.legend()
plt.tight_layout()
print('Histograma del total de ganancias consumidas por mes del plan surf y ultimate')
print('\n')
plt.show()
# Out:
# Histograma del total de ganancias consumidas por mes del plan surf y ultimate

# %% [markdown]
# Observacion del histograma
#
# Según el histograma que muestra la distribución de los ingresos mensuales totales de los planes «Surf» y «Ultimate»:
#
# Plan Surf (barras azul celeste): El histograma de los ingresos del plan «Surf» muestra una distribución más amplia y dispersa. Esto genera una amplia gama de ingresos mensuales, a menudo superiores a la cuota base, lo que contribuye a una cola más larga en el lado derecho de la distribución. La observación previa de que los ingresos de «Surf» tienden a aumentar a lo largo del año coincide con esto, ya que los usuarios incurren en más cargos adicionales.
#
# Plan Ultimate (barras grises): El histograma de los ingresos del plan «Ultimate» parece estar mucho más concentrado, mostrando principalmente una alta frecuencia en torno a su cuota mensual base (aproximadamente 70 $). Incluso con bins=2 en el código de trazado, el patrón general indica que la gran mayoría de los usuarios del plan "Ultimate" se mantienen dentro de sus generosos límites de consumo, o al menos no incurren en cargos adicionales significativos. Esto se traduce en un flujo de ingresos muy estable y predecible para Megaline proveniente de los suscriptores del plan "Ultimate", concentrado en torno al pago mensual fijo.
#
# Conclusión general: El plan "Ultimate" genera consistentemente ingresos por usuario más estables y generalmente más altos, impulsados ​principalmente por su tarifa mensual fija y más elevada. En contraste, los ingresos del plan "Surf" son más variables, ya que muchos usuarios superan sus límites de consumo y, por lo tanto, incurren en cargos adicionales. Esta flexibilidad en la facturación del plan "Surf" permite aumentar los ingresos de quienes consumen más de lo que incluyen sus beneficios, pero el plan "Ultimate" proporciona un flujo de ingresos base más predecible.

# %%
# Varianza con grafico de caja
## Calculate the measures of statistical tendency msg per month for each plan
#calcular la varianza
var_revenue_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['mb_cons'].var().reset_index()

# Now, we can filter this result to get the average for each plan separately
revenuevar_mbxmes_plansurf = var_revenue_per_month_per_plan[var_revenue_per_month_per_plan['plan_name'] == 'surf']
revenuevar_mbxmes_planult = var_revenue_per_month_per_plan[var_revenue_per_month_per_plan['plan_name'] == 'ultimate']

print(f'Varianza de ingresos consumidos\n de ambos planes')
print('\n')
print('Varianza de ingesos consumidos\n plan surf')
print('\n')
print(revenuevar_mbxmes_plansurf)
print('\n')
print('Varianza de ingresos consumidos\n plan ultimate')
print('\n')
print(revenuevar_mbxmes_planult)
print('\n')
# Out:
# Varianza de ingresos consumidos
#  de ambos planes
#
#
# Varianza de ingesos consumidos
#  plan surf
#
#
#     month plan_name       mb_cons
# 0       0      surf  0.000000e+00
# 2       1      surf  1.820458e+07
# 4       2      surf  4.356411e+07
# 6       3      surf  6.810013e+07
# 8       4      surf  5.891614e+07
# 10      5      surf  6.135230e+07
# 12      6      surf  4.904029e+07
# 14      7      surf  6.456342e+07
# 16      8      surf  7.448754e+07
# 18      9      surf  5.121568e+07
# 20     10      surf  6.240718e+07
# 22     11      surf  5.705889e+07
# 24     12      surf  7.200821e+07
#
#
# Varianza de ingresos consumidos
#  plan ultimate
#
#
#     month plan_name       mb_cons
# 1       0  ultimate  0.000000e+00
# 3       1  ultimate  1.636639e+07
# 5       2  ultimate  3.755824e+07
# 7       3  ultimate  1.400620e+08
# 9       4  ultimate  8.825817e+07
# 11      5  ultimate  5.669713e+07
# 13      6  ultimate  7.188493e+07
# 15      7  ultimate  6.828502e+07
# ...

# %%
# Ambos boxplot de ingresos por mes del plan surf y plan ultimate

import matplotlib.pyplot as plt
import numpy as np

var_revenue_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['monthly_revenue'].var().reset_index()

# Now, we can filter this result to get the average for each plan separately
revar_mbxmes_plansurf = var_revenue_per_month_per_plan[var_revenue_per_month_per_plan['plan_name'] == 'surf']
revar_mbxmes_planult = var_revenue_per_month_per_plan[var_revenue_per_month_per_plan['plan_name'] == 'ultimate']

# Prepare data for box plots
data_to_plot = [
    revar_mbxmes_plansurf['monthly_revenue'],
    revar_mbxmes_planult['monthly_revenue']
]

labels = ['Plan Surf', 'Plan Ultimate']

fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot(data_to_plot, vert=False, labels=labels, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'),
           whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'),
           flierprops=dict(marker='o', markerfacecolor='red', markersize=6,
                           linestyle='none'))

ax.set_xlabel('ingresos por mes consumidos')
ax.set_title('Distribución de la varianza de ingresos mensuales Consumidos por Plan')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
print(f'Grafico de caja de la varianza del total de ingresos\n consumidos por mes del plan surf y ultimate')
print('\n')

plt.show()
# Out:
# Grafico de caja de la varianza del total de ingresos
#  consumidos por mes del plan surf y ultimate

# %% [markdown]
# Observación de la varianza con grafico de caja
#
# Observación del gráfico de caja de la varianza de ingresos mensuales:
#
# **Varianza (dispersión de los ingresos mensuales):**
#
# *   **Plan Surf (`revar_mbxmes_plansurf`):** El gráfico de caja para el plan Surf muestra una dispersión significativamente mayor en la varianza de los ingresos mensuales. Esto significa que los ingresos generados por los usuarios del plan Surf fluctúan considerablemente de un mes a otro. La caja es más ancha y podría tener un rango intercuartílico (IQR) más grande, lo que indica que hay una mayor inconsistencia en los ingresos mensuales. Los bigotes y posibles valores atípicos también pueden extenderse más, reforzando la idea de una alta variabilidad.
#
# *   **Plan Ultimate (`revar_mbxmes_planult`):** En contraste, el gráfico de caja para el plan Ultimate es mucho más compacto. Esto sugiere que la varianza de los ingresos mensuales de este plan es considerablemente menor y más estable. La caja más estrecha y un IQR más pequeño indican que los ingresos por usuario del plan Ultimate son más predecibles todos hacercandose a la cuota fija y se agrupan más estrechamente alrededor de un valor central, que es principalmente la tarifa mensual de $70.
#
# **Conclusiones:**
#
# *   **Estabilidad de ingresos:** El plan Ultimate genera un flujo de ingresos mucho más estable y predecible para Megaline. La baja varianza de sus ingresos mensuales significa que la empresa puede proyectar mejor sus ganancias de este segmento de clientes.
#
# *   **Inestabilidad y potencial de ingresos extra del plan Surf:** El plan Surf, aunque puede generar picos de ingresos debido a que los usuarios exceden sus límites, presenta una alta variabilidad. Esto hace que sus ingresos sean menos predecibles. Sin embargo, esta variabilidad también indica que existe un potencial significativo de ingresos adicionales provenientes de los recargos por uso extra (minutos, mensajes, datos).
#
# En resumen, el análisis de la varianza confirma que el plan Ultimate es una fuente de ingresos más constante y confiable, mientras que el plan Surf es más fluctuante, con una mayor dependencia de los cargos por excedentes para aumentar los ingresos.

# %%
#Desviacion estandar con grafico de caja

## Calculate the measures of statistical tendency msg per month for each plan
#calcular la desviaciion estandart
desv_est_revenue_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['mb_cons'].std().reset_index()

# Now, we can filter this result to get the average for each plan separately
revstd_mbxmes_plansurf = desv_est_revenue_per_month_per_plan[desv_est_revenue_per_month_per_plan['plan_name'] == 'surf']
revstd_mbxmes_planult = desv_est_revenue_per_month_per_plan[desv_est_revenue_per_month_per_plan['plan_name'] == 'ultimate']

print(f'Desviación estandar de ingresos consumidos\n de ambos planes')
print('\n')
print('Desviacion estandar de ingresos consumidos\n por mes del plan surf')
print('\n')
print(revstd_mbxmes_plansurf)
print('\n')
print('Desviaciónestandar de ingresos consumidos\n por mes del plan ultimate')
print('\n')
print(revstd_mbxmes_planult)
print('\n')
# Out:
# Desviación estandar de ingresos consumidos
#  de ambos planes
#
#
# Desviacion estandar de ingresos consumidos
#  por mes del plan surf
#
#
#     month plan_name      mb_cons
# 0       0      surf     0.000000
# 2       1      surf  4266.682318
# 4       2      surf  6600.311394
# 6       3      surf  8252.280179
# 8       4      surf  7675.684906
# 10      5      surf  7832.770952
# 12      6      surf  7002.877384
# 14      7      surf  8035.136677
# 16      8      surf  8630.616433
# 18      9      surf  7156.513449
# 20     10      surf  7899.821451
# 22     11      surf  7553.733390
# 24     12      surf  8485.765376
#
#
# Desviaciónestandar de ingresos consumidos
#  por mes del plan ultimate
#
#
#     month plan_name       mb_cons
# 1       0  ultimate      0.000000
# 3       1  ultimate   4045.540044
# 5       2  ultimate   6128.477508
# 7       3  ultimate  11834.778697
# 9       4  ultimate   9394.582137
# 11      5  ultimate   7529.749928
# ...

# %%
# Grafico de caja

import matplotlib.pyplot as plt
import numpy as np

std_revenue_per_month_per_plan = dfcompilated.groupby(['month', 'plan_name'])['monthly_revenue'].std().reset_index()

# Now, we can filter this result to get the average for each plan separately
revstd_mbxmes_plansurf = std_revenue_per_month_per_plan[std_revenue_per_month_per_plan['plan_name'] == 'surf']
revstd_mbxmes_planult = std_revenue_per_month_per_plan[std_revenue_per_month_per_plan['plan_name'] == 'ultimate']

# Prepare data for box plots
data_to_plot = [
    revstd_mbxmes_plansurf['monthly_revenue'],
    revstd_mbxmes_planult['monthly_revenue']
]

labels = ['Plan Surf', 'Plan Ultimate']

fig, ax = plt.subplots(figsize=(10, 6))

ax.boxplot(data_to_plot, vert=False, labels=labels, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'),
           whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'),
           flierprops=dict(marker='o', markerfacecolor='red', markersize=6,
                           linestyle='none'))

ax.set_xlabel('ingresos por mes consumidos')
ax.set_title('Distribución de la desviacion estandar de ingresos mensuales Consumidos por Plan')

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
print(f'Grafico de caja de la desviacion estandar del total de ingresos\n consumidos por mes del plan surf y ultimate')
print('\n')

plt.show()
# Out:
# Grafico de caja de la desviacion estandar del total de ingresos
#  consumidos por mes del plan surf y ultimate

# %% [markdown]
# Observación de la desviación estandar
# El diagrama de caja que ilustra la desviación estándar de los ingresos mensuales resalta diferencias significativas en la dispersión de ingresos entre los planes Surf y Ultimate.
#
# Para el plan Surf, se observa una distribución mucho más amplia en el diagrama de caja. Esto indica una mayor variabilidad y fluctuación en los ingresos mensuales, lo que sugiere una menor previsibilidad. Esta variabilidad probablemente se deba a que los usuarios superan sus límites de minutos, mensajes o internet, lo que genera cargos adicionales.
#
# En contraste, el plan Ultimate muestra un diagrama de caja considerablemente más compacto. Esto significa una variabilidad menor y más estable en los ingresos mensuales. Los ingresos de este plan son altamente predecibles, agrupándose en torno a su tarifa mensual fija de $70. La caja más estrecha y el rango intercuartil (RIC) menor reflejan esta consistencia.
#
# En conclusión, el plan Ultimate ofrece un flujo de ingresos significativamente más estable y predecible, lo que facilita la proyección de ganancias. Si bien el plan Surf tiene el potencial de generar picos de ingresos más altos debido a los cargos por exceso de consumo, sus ingresos son menos predecibles debido a esta alta variabilidad. Este análisis confirma que el Plan Ultimate es una fuente de ingresos constante y fiable, mientras que los ingresos del Plan Surf son más fluctuantes y dependen de cargos adicionales por el uso.

# %% [markdown]
# [Elabora las conclusiones sobre cómo difiere el ingreso entre los planes.]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor  v2    </b> <a class="tocSkip"></a>
#
# Bien hecho. Vemos que los planes se diferencian en el ingreso, a pesar de que el consumo de sus usuarios es muy similar. Esto ocurre porque la estructura de costos de cada plan define intervalos de consumo diferentes, para surf los usuarios tienden a salirse de esos rangos pero los de ultimate no
#
# </div>

# %% [markdown]
# ## Prueba las hipótesis estadísticas

# %% [markdown]
# [Prueba la hipótesis de que son diferentes los ingresos promedio procedentes de los usuarios de los planes de llamada Ultimate y Surf.]

# %% [markdown]
# [Elabora las hipótesis nula y alternativa, escoge la prueba estadística, determina el valor alfa.]

# %% [markdown]
# Prueba de hipótesis para los ingresos promedio Para probar la hipótesis de que los ingresos promedio de los usuarios de los planes Ultimate y Surf son diferentes, debemos seguir estos pasos:
#
# Formular las hipótesis:
#
# Hipótesis Nula (H₀): El ingreso promedio de los usuarios del plan Ultimate es igual al ingreso promedio de los usuarios del plan Surf. (H₀: μ_ultimate = μ_surf) Hipótesis Alternativa (H₁): El ingreso promedio de los usuarios del plan Ultimate es diferente al ingreso promedio de los usuarios del plan Surf. (H₁: μ_ultimate ≠ μ_surf) Elegir la prueba estadística: Dado que estamos comparando las medias de dos poblaciones independientes (usuarios de Surf y usuarios de Ultimate) y no conocemos la desviación estándar de la población, utilizaremos una prueba t de Student para dos muestras independientes.
#
# Determinar el valor alfa (nivel de significancia): Estableceremos un nivel de significancia (α) de 0.05. Esto significa que estamos dispuestos a aceptar un 5% de probabilidad de rechazar la hipótesis nula cuando en realidad es verdadera.

# %% [markdown]
# [Elabora las hipótesis nula y alternativa, escoge la prueba estadística, determina el valor alfa.]

# %%
surf_revenue = dfcompilated[dfcompilated['plan_name'] == 'surf']['monthly_revenue']
ultimate_revenue = dfcompilated[dfcompilated['plan_name'] == 'ultimate']['monthly_revenue']

print(surf_revenue.mean())
print(ultimate_revenue.mean())
# Out:
# 60.41873337555414
# 72.2817679558011

# %%
# Prueba las hipótesis de que el ingreso promedio de los usuarios
# del plan Ultimate es igual al ingreso promedio de los usuarios del plan Surf Ho.

surf_revenue = dfcompilated[dfcompilated['plan_name'] == 'surf']['monthly_revenue']
ultimate_revenue = dfcompilated[dfcompilated['plan_name'] == 'ultimate']['monthly_revenue']

#results = st.ttest_ind(surf_revenue, ultimate_revenue, equal_var=False)
results = st.ttest_ind(surf_revenue, ultimate_revenue, equal_var=False)

print(f"P-Value: {results.pvalue}")

if results.pvalue < 0.05:
    print("Rechazamos la hipótesis nula: Los ingresos son diferentes.")
else:
    print("No podemos rechazar la hipótesis nula.")

print(f"El plan ultimate(${ultimate_revenue.mean()}) tienen un promedio mayor que el plan surf(${surf_revenue.mean()})")
# Out:
# P-Value: 5.470027062540144e-16
# Rechazamos la hipótesis nula: Los ingresos son diferentes.
# El plan ultimate($72.2817679558011) tienen un promedio mayor que el plan surf($60.41873337555414)

# %% [markdown]
# [Prueba la hipótesis de que el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones.]

# %% [markdown]
# Realizamos algunos pasos previos Antes de contestar [Prueba la hipótesis de que el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones.]

# %%
# fusionar el dataframe dfcompilated y sumarle del df megaline_users_0  la ciudad 'city'

df_comp_city = dfcompilated.merge(megaline_users_0[['user_id', 'city']], on='user_id', how='outer') #cambie how='left' por 'outer'
print(df_comp_city.head())
# Out:
#    user_id plan_name  month  calls_cons  minutes_cons  messages_cons  mb_cons  \
# 0     1000  ultimate     12          16           124             11     1899
# 1     1006  ultimate     11           2            10             15     2066
# 2     1006  ultimate     12           9            59            139    32085
# 3     1008  ultimate     10          71           476             21    17083
# 4     1008  ultimate     11          63           446             37    23652
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute  \
# ...

# %%
#encontra valores nulos al parecer no hay
df_comp_city['city'].isna().sum()
# Out:
# 0

# %%
#Encontar Valores nulos y rellenar con fillna por si acaso
df_comp_city.fillna('Unknown', inplace=True)

# %%
print(df_comp_city['city'].head())
# Out:
# 0     Atlanta-Sandy Springs-Roswell, GA MSA
# 1    San Francisco-Oakland-Berkeley, CA MSA
# 2    San Francisco-Oakland-Berkeley, CA MSA
# 3         Orlando-Kissimmee-Sanford, FL MSA
# 4         Orlando-Kissimmee-Sanford, FL MSA
# Name: city, dtype: object

# %%
# Prueba las hipótesis de que el ingreso promedio de los usuarios
# del área NY-NJ es diferente al de los usuarios de otras regiones.

area_nynj = df_comp_city[df_comp_city['city'] == 'New York-Newark-Jersey City, NY-NJ-PA MSA']['monthly_revenue'].mean()
area_other = df_comp_city[df_comp_city['city'] != 'New York-Newark-Jersey City, NY-NJ-PA MSA']['monthly_revenue'].mean()

#
print(area_nynj)
print('\n')
print(area_other)
# Out:
# 59.89510582010582
#
#
# 64.98328831168831

# %% [markdown]
# Aqui se resuelve [Prueba la hipótesis de que el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones.]

# %%
# Prueba las hipótesis de que el ingreso promedio de los usuarios
# del área NY-NJ es diferente al de los usuarios de otras regiones.]

area_nynji = df_comp_city[df_comp_city['city'] == 'New York-Newark-Jersey City, NY-NJ-PA MSA']['monthly_revenue']
area_otheri = df_comp_city[df_comp_city['city'] != 'New York-Newark-Jersey City, NY-NJ-PA MSA']['monthly_revenue']

#results = st.ttest_ind(surf_revenue, ultimate_revenue, equal_var=False)
results = st.ttest_ind(surf_revenue, ultimate_revenue, equal_var=False)

print(f"P-Value: {results.pvalue}")

if results.pvalue < 0.05:
    print("Rechazamos la hipótesis nula: Los ingresos son diferentes.")
else:
    print("No podemos rechazar la hipótesis nula.")

print(f"Las otras areas(${area_other.mean()}) tienen un promedio mayor que la area de NY-NJ (${area_nynji.mean()})")
# Out:
# P-Value: 5.470027062540144e-16
# Rechazamos la hipótesis nula: Los ingresos son diferentes.
# Las otras areas($64.98328831168831) tienen un promedio mayor que la area de NY-NJ ($59.89510582010582)

# %%
def get_plan_health_report(df, plan_name):
    """
    Genera un reporte ejecutivo de métricas clave por plan.
    """
    data = dfcompilated[dfcompilated['plan_name'] == plan_name]
    report = {
        "Plan": plan_name,
        "Usuarios Únicos": data['user_id'].nunique(),
        "Ingreso Promedio Mensual (ARPU)": round(data['monthly_revenue'].mean()),
        "Ingreso Total Anual Estimado": round(data['monthly_revenue'].sum())

    }
    return pd.Series(report)

print("--- REPORTE EJECUTIVO ---")
print(get_plan_health_report(dfcompilated, 'surf'))
print("\n")
print(get_plan_health_report(dfcompilated, 'ultimate'))
# Out:
# --- REPORTE EJECUTIVO ---
# Plan                                surf
# Usuarios Únicos                      339
# Ingreso Promedio Mensual (ARPU)       60
# Ingreso Total Anual Estimado       95401
# dtype: object
#
#
# Plan                               ultimate
# Usuarios Únicos                         161
# Ingreso Promedio Mensual (ARPU)          72
# Ingreso Total Anual Estimado          52332
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor    v2        </b> <a class="tocSkip"></a>
#
# Bien hecho con los tests, fueron realizados de forma correcta.
#
# Es importante mencionar que el t-test asume que las dos muestras tienen varianzas iguales Para verificar esa igualdad de varianzas podemos usar el **test de Levene**. Este nos dice si la variabilidad entre los grupos es *estadísticamente diferente*. En futuros notebooks podrías utilizar este test para decidir sobre la igualdad de varianzas. En corto, el flujo sería así
#
# 1. Usamos `levene()` para verificar si las varianzas son iguales.
# 2. Dependiendo del resultado, usamos `ttest_ind()` con el argumento `equal_var`:
#    - `equal_var=True` si Levene dice que las varianzas son iguales (p > 0.05).
#    - `equal_var=False` si Levene dice que las varianzas son diferentes (p < 0.05).
#
# </div>

# %% [markdown]
# ## Conclusión general
#
# [En esta sección final, enumera tus conclusiones importantes. Asegúrate de que estas abarquen todas las decisiones (suposiciones) importantes que adoptaste y que determinaron la forma elegida para procesar y analizar los datos.]

# %% [markdown]
# ## Conclusión General del Análisis de Tarifas Megaline
#
# ### 1. Comportamiento en Llamadas
#
# *   **Plan Surf:** Los usuarios del plan Surf muestran un patrón de consumo de minutos más variable, con una tendencia a usar un número de minutos que, en muchos casos, se acerca o excede su límite de 500 minutos incluidos. Esto se refleja en un aumento de los ingresos a lo largo del año debido a cargos por excedentes.
# *   **Plan Ultimate:** Los usuarios de Ultimate, con un límite de 3000 minutos, consumen en promedio una cantidad similar de minutos a los usuarios de Surf, pero rara vez se acercan a su límite. Su consumo es más estable, lo que implica menos cargos adicionales por minutos.
#
# ### 2. Comportamiento en Mensajes
#
# *   **Plan Surf:** Los usuarios de Surf, con un límite de 50 mensajes, tienen un consumo de mensajes más 'apretado' debajo de su límite.
# *   **Plan Ultimate:** A pesar de un generoso límite de 1000 mensajes, la mayoría de los usuarios de Ultimate envían un número de mensajes muy inferior. La distribución de su consumo es más concentrada en la parte inferior, indicando que el beneficio no es aprovechado al máximo y rara vez se incurre en cargos por excedentes.
#
# ### 3. Comportamiento en Internet (Datos)
#
# *   **Plan Surf:** El consumo de datos de los usuarios de Surf (límite de 15 GB) a menudo excede su límite, especialmente en la segunda mitad del año y los meses de mayor actividad como diciembre, lo que resulta en cargos adicionales significativos y un aumento en los ingresos promedio a lo largo del año.
# *   **Plan Ultimate:** Los usuarios de Ultimate (límite de 30 GB) consumen más datos en promedio que los de Surf, pero casi nunca alcanzan su límite. Esto significa que los ingresos por datos adicionales son mínimos para este plan, ya que la asignación es excesivamente alta para el uso promedio.
#
# ### 4. Ingresos Mensuales por Plan
#
# *   **Plan Surf:** El ingreso mensual promedio del plan Surf es más variable, comenzando en la tarifa base y aumentando progresivamente a lo largo del año a medida que los usuarios incurren en cargos por excedentes de minutos, mensajes e internet. La desviación estándar y la varianza de los ingresos son significativamente más altas, lo que indica una menor predictibilidad.
# *   **Plan Ultimate:** El ingreso mensual promedio del plan Ultimate es consistentemente más alto y estable, principalmente debido a su tarifa mensual fija más elevada ($70). La variabilidad en los ingresos es mínima, ya que los usuarios rara vez superan sus generosos límites. Esto hace que los ingresos del plan Ultimate sean mucho más predecibles y confiables.
#
# ### 5. Comparación de Ingresos Promedio (Hipótesis 1)
#
# *   La prueba t de Student mostró un p-value extremadamente bajo (5.47e-16), lo que nos lleva a **rechazar la hipótesis nula**. Esto significa que existe una **diferencia estadísticamente significativa en los ingresos promedio** generados por los usuarios de los planes Surf y Ultimate. El plan Ultimate genera un ingreso promedio por usuario mayor y más estable.
#
# ### 6. Comparación de Ingresos por Región (Hipótesis 2)
#
# *   Se encontró que el ingreso promedio de los usuarios del área NY-NJ (59.89 dolares) es diferente y menor que el ingreso promedio de los usuarios de otras regiones (64.98 dolares). La hipótesis de que el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones fue confirmada, y las otras áreas tienen un promedio mayor. Sin embargo el Area de NY-NJ es una area considerable por sus altos ingresos a comparacion de la suma de todas las demas areas.
#
# ### 7. Reporte final
#
# En este reporte podemos observar claramente que en ingreso total anual estimado parael plan surf es de 95401 mientras que para el plan ultimate es de 52332 por lo que se observa un mayor ingreso el plan surf, por lo cual es importante resaltar la importancia del plan ultimate ya que genera un ingreso estable pero el plan surf pese a no ser tan constante presenta picos que generan un ingreso mayor.
#
#
# ### Conclusión Final y Recomendación
#
# Aunque el plan Surf genera ingresos adicionales significativos a través de cargos por excedentes, sus ingresos son menos predecibles debido a la alta variabilidad en el consumo de los usuarios. El plan Ultimate, por otro lado, proporciona un flujo de ingresos mucho más **estable, predecible y consistentemente más alto** por usuario, gracias a su tarifa fija superior y límites generosos.
#
# Para el departamento comercial de Megaline, el **plan Ultimate es el que genera más ingresos de manera consistente y predecible**. Aunque los usuarios de Surf pueden generar picos de ingresos por excedentes, la estabilidad y el valor base más alto del plan Ultimate lo convierten en la opción más rentable a largo plazo para la empresa. Es importante considerar que los límites generosos del plan Ultimate a menudo no se aprovechan por completo, lo que podría ser una oportunidad para optimizar el plan o sus estrategias de marketing para resaltar el valor real y aún mas impulsar el plan Surf que genera una ganacia aún mayor.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor     v2</b> <a class="tocSkip"></a>
#
# ¡Muy buenas conclusiones! Destaco el acierto de incluir valores relevantes de las métricas clave, lo cual aporta claridad y sustento al análisis. Además, resumiste de forma efectiva los hallazgos principales. ¡Buen trabajo!
#
#
#
# </div>

# %% [markdown]
# <div class='alert alert-block alert-info'>
# <b>Re: Muchas gracias por las observaciones espero haberlo hecho correctamente </b> <a class='tocSkip'></a>
# </div>
